# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install -i https://test.pypi.org/simple/ supervision==0.3.0
# !pip install -q transformers
# !pip install -q pytorch-lightning
# !pip install -q roboflow
# !pip install -q timm
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# Collecting supervision==0.3.0
#   Downloading https://test-files.pythonhosted.org/packages/9c/29/e30c575a94cb121417cd7725aecb6bbf78d14d923f42e0bce7cf7de9b3eb/supervision-0.3.0-py3-none-any.whl (21 kB)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from supervision==0.3.0) (1.25.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from supervision==0.3.0) (4.8.0.76)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from supervision==0.3.0) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.3.0) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.3.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.3.0) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.3.0) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.3.0) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.3.0) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.3.0) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.3.0) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->supervision==0.3.0) (1.16.0)
# Installing collected packages: supervision
# Successfully installed supervision-0.3.0
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 812.3/812.3 kB 11.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 868.8/868.8 kB 52.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.2/76.2 kB 3.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.9 MB/s eta 0:00:00

# %%
import torch
# !nvcc --version
TORCH_VERSION = ".".join(torch.__version__.split(".")[:2])
CUDA_VERSION = torch.__version__.split("+")[-1]
print("torch: ", TORCH_VERSION, "; cuda: ", CUDA_VERSION)

import roboflow
import supervision
import transformers
import pytorch_lightning

print(
    "roboflow:", roboflow.__version__,
    "; supervision:", supervision.__version__,
    "; transformers:", transformers.__version__,
    "; pytorch_lightning:", pytorch_lightning.__version__
)
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0
# torch:  2.3 ; cuda:  cu121
# roboflow: 1.1.34 ; supervision: 0.3.0 ; transformers: 4.41.2 ; pytorch_lightning: 2.3.1

# %%
# %cd {HOME}
# !wget https://media.roboflow.com/notebooks/examples/dog.jpeg
# Out:
# /content
# --2024-07-04 06:02:39--  https://media.roboflow.com/notebooks/examples/dog.jpeg
# Resolving media.roboflow.com (media.roboflow.com)... 34.110.133.209
# Connecting to media.roboflow.com (media.roboflow.com)|34.110.133.209|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 106055 (104K) [image/jpeg]
# Saving to: ‘dog.jpeg’
#
# dog.jpeg            100%[===================>] 103.57K  --.-KB/s    in 0.001s
#
# 2024-07-04 06:02:39 (116 MB/s) - ‘dog.jpeg’ saved [106055/106055]

# %%
import os

IMAGE_NAME = "dog.jpeg"
IMAGE_PATH = os.path.join(HOME, IMAGE_NAME)

# %%
import torch
from transformers import DetrForObjectDetection, DetrImageProcessor


# settings
DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
CHECKPOINT = 'facebook/detr-resnet-50'
CONFIDENCE_TRESHOLD = 0.5
IOU_TRESHOLD = 0.8

image_processor = DetrImageProcessor.from_pretrained(CHECKPOINT)
model = DetrForObjectDetection.from_pretrained(CHECKPOINT)
model.to(DEVICE)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-41-e67ca3e9a1c8> in <cell line: 12>()
#      10
#      11 image_processor = DetrImageProcessor.from_pretrained(CHECKPOINT)
# ---> 12 model = DetrForObjectDetection.from_pretrained(CHECKPOINT)
#      13 model.to(DEVICE)
#
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3624         with ContextManagers(init_contexts):
#    3625             # Let's make sure we don't run the init function of buffer modules
# -> 3626             model = cls(config, *model_args, **model_kwargs)
#    3627
#    3628         # make sure we use the model's config since the __init__ call might have copied it
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/detr/modeling_detr.py in __init__(self, config)
#    1350
#    1351         # DETR encoder-decoder model
# -> 1352         self.model = DetrModel(config)
#    1353
#    1354         # Object detection heads
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/detr/modeling_detr.py in __init__(self, config)
#    1182
#    1183         # Create backbone + positional encoding
# -> 1184         backbone = DetrConvEncoder(config)
#    1185         object_queries = build_position_encoding(config)
#    1186         self.backbone = DetrConvModel(backbone, object_queries)
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/detr/modeling_detr.py in __init__(self, config)
#     349             # We default to values which were previously hard-coded. This enables configurability from the config
#     350             # using backbone arguments, while keeping the default behavior the same.
# --> 351             requires_backends(self, ["timm"])
#     352             kwargs = getattr(config, "backbone_kwargs", {})
#     353             kwargs = {} if kwargs is None else kwargs.copy()
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/import_utils.py in requires_backends(obj, backends)
#    1461     failed = [msg.format(name) for available, msg in checks if not available()]
#    1462     if failed:
# -> 1463         raise ImportError("".join(failed))
#    1464
#    1465
#
# ImportError:
# DetrConvEncoder requires the timm library but it was not found in your environment. You can install it with pip:
# `pip install timm`. Please note that you may need to restart your runtime after installation.
#
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
ls
# Out:
# dog.jpeg  drive/  sample_data/

# %%
# Load the DETR Model from Hugging Face
processor = DetrImageProcessor.from_pretrained("facebook/detr-resnet-50")
model = DetrForObjectDetection.from_pretrained("facebook/detr-resnet-50")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-34-f3b5159057e9> in <cell line: 3>()
#       1 # Load the DETR Model from Hugging Face
#       2 processor = DetrImageProcessor.from_pretrained("facebook/detr-resnet-50")
# ----> 3 model = DetrForObjectDetection.from_pretrained("facebook/detr-resnet-50")
#       4
#
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3624         with ContextManagers(init_contexts):
#    3625             # Let's make sure we don't run the init function of buffer modules
# -> 3626             model = cls(config, *model_args, **model_kwargs)
#    3627
#    3628         # make sure we use the model's config since the __init__ call might have copied it
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/detr/modeling_detr.py in __init__(self, config)
#    1350
#    1351         # DETR encoder-decoder model
# -> 1352         self.model = DetrModel(config)
#    1353
#    1354         # Object detection heads
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/detr/modeling_detr.py in __init__(self, config)
#    1182
#    1183         # Create backbone + positional encoding
# -> 1184         backbone = DetrConvEncoder(config)
#    1185         object_queries = build_position_encoding(config)
#    1186         self.backbone = DetrConvModel(backbone, object_queries)
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/detr/modeling_detr.py in __init__(self, config)
#     349             # We default to values which were previously hard-coded. This enables configurability from the config
#     350             # using backbone arguments, while keeping the default behavior the same.
# --> 351             requires_backends(self, ["timm"])
#     352             kwargs = getattr(config, "backbone_kwargs", {})
#     353             kwargs = {} if kwargs is None else kwargs.copy()
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/import_utils.py in requires_backends(obj, backends)
#    1461     failed = [msg.format(name) for available, msg in checks if not available()]
#    1462     if failed:
# -> 1463         raise ImportError("".join(failed))
#    1464
#    1465
#
# ImportError:
# DetrConvEncoder requires the timm library but it was not found in your environment. You can install it with pip:
# `pip install timm`. Please note that you may need to restart your runtime after installation.
#
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import timm
print("timm version:", timm.__version__)
# Out:
# timm version: 1.0.7
