# %%
#Checking the directory of dataset
# !ls 'drive/MyDrive/plant_disease_detection'
# Out:
# colab_notebooks  dataset  logs	models

# %%
# !pip install timm
# Out:
# Requirement already satisfied: timm in /usr/local/lib/python3.10/dist-packages (1.0.7)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from timm) (2.3.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm) (0.18.0+cu121)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm) (6.0.1)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (from timm) (0.23.4)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm) (0.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (3.15.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (24.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->timm) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->timm) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->timm) (12.5.40)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (1.25.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->timm) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (2024.6.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->timm) (1.3.0)

# %%
import os
import time
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, models, transforms
from torch.utils.data import DataLoader
import timm
import logging
torch.cuda.empty_cache()


# Import PyTorch XLA and TPU libraries

import torch.cuda.amp as amp
from torch.cuda.amp import autocast, GradScaler

import cProfile
import pstats

from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import numpy as np

# %%
# Setup logging
os.makedirs('drive/MyDrive/plant_disease_detection/logs', exist_ok=True)
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s', handlers=[
    logging.FileHandler("drive/MyDrive/plant_disease_detection/logs/efficientnet_v2_s_logs.log"),
    logging.StreamHandler()
])
logger = logging.getLogger()

# %%
#Defining data transformations

#transforms.RandomResizedCrop(224)=>Randomly crops the image to a size of 224x224 pixels
#reason:Helps in augmenting the dataset by introducing variations in the input images.

#transforms.RandomHorizontalFlip()=>Randomly flips the image horizontally with a probability of 0.5
#reason:Introduces more variations and helps in making the model invariant to the orientation of the images.

#transforms.ToTensor()=>Converts the image to a PyTorch tensor
#reason:Changes the data type from PIL Image or numpy.ndarray to torch.Tensor

#transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])=>Normalizes the image by subtracting the mean [0.485, 0.456, 0.406] and dividing by the standard deviation [0.229, 0.224, 0.225] for each channel (RGB)
#reason:This normalization helps in speeding up convergence during training by standardizing the input

# Define data transformations
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(degrees=30),
        transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ]),
    'valid': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ]),
}

# %%
#Loading the images from train and validation folder and transform them
data_dir = 'drive/MyDrive/plant_disease_detection/dataset'
image_datasets = {x: datasets.ImageFolder(root=f"{data_dir}/{x}", transform=data_transforms[x]) for x in ['train', 'valid']}

# Optimized DataLoader setup
batch_size = 64
num_workers = 8

dataloaders = {
    'train': DataLoader(image_datasets['train'], batch_size=batch_size, shuffle=True, num_workers=num_workers, prefetch_factor=2, pin_memory=True),
    'valid': DataLoader(image_datasets['valid'], batch_size=batch_size, shuffle=False, num_workers=num_workers, prefetch_factor=2, pin_memory=True),
}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'valid']}
class_names = image_datasets['train'].classes
print(len(dataloaders['train']))
print(class_names)
print(len(class_names))
# Out:
# 437
# ['Pepper,_bell___Bacterial_spot', 'Pepper,_bell___healthy', 'Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy', 'Tomato___Bacterial_spot', 'Tomato___Early_blight', 'Tomato___Late_blight', 'Tomato___Leaf_Mold', 'Tomato___Septoria_leaf_spot', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Tomato___Target_Spot', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Tomato___Tomato_mosaic_virus', 'Tomato___healthy']
# 15

# %%
# Profile the DataLoader
def profile_dataloader(dataloader, num_batches=10):
    import cProfile, pstats
    profiler = cProfile.Profile()
    profiler.enable()

    for i, _ in enumerate(dataloader):
        if i >= num_batches:
            break

    profiler.disable()
    stats = pstats.Stats(profiler).sort_stats('cumtime')
    stats.print_stats(10)  # Print top 10 bottlenecks

# Profile the training DataLoader
print("Profiling DataLoader...")
profile_dataloader(dataloaders['train'])
# Out:
# Profiling DataLoader...
#          7339 function calls (7337 primitive calls) in 54.540 seconds
#
#    Ordered by: cumulative time
#    List reduced from 246 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        47    0.001    0.000   43.610    0.928 /usr/lib/python3.10/threading.py:288(wait)
#       319   43.610    0.137   43.610    0.137 {method 'acquire' of '_thread.lock' objects}
#        11    0.000    0.000   43.592    3.963 /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:626(__next__)
#        11    0.000    0.000   43.589    3.963 /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:1299(_next_data)
#        15    0.000    0.000   43.588    2.906 /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:1266(_get_data)
#        21    0.000    0.000   43.587    2.076 /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:1120(_try_get_data)
#        21    0.000    0.000   43.587    2.076 /usr/lib/python3.10/queue.py:154(get)
#         1    0.000    0.000   10.770   10.770 /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:1478(__del__)
#         1    0.000    0.000   10.770   10.770 /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:1401(_shutdown_workers)
#         8    0.000    0.000   10.768    1.346 /usr/lib/python3.10/multiprocessing/process.py:142(join)

# %%
# Initialize EfficientNetV2-L model
model = timm.create_model('tf_efficientnetv2_s', pretrained=True, num_classes=len(class_names))
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.cuda.empty_cache()
model = model.to(device)
print(device)

# Define criterion, optimizer, and scheduler
criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=0.0025)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

# AMP GradScaler initialization
scaler = GradScaler()
# Out:
# cuda

# %%
# Training function with AMP and Gradient Accumulation
def train_model(model, criterion, optimizer, scheduler, dataloaders, dataset_sizes, device, num_epochs=25):
    since = time.time()
    best_model_wts = model.state_dict()
    best_acc = 0.0
    accumulation_steps = 4  # Number of batches to accumulate gradients over

    for epoch in range(num_epochs):
        print(f"Epoch {epoch}/{num_epochs - 1}")
        print('-' * 10)
        logger.info(f"Epoch {epoch}/{num_epochs - 1}")
        logger.info('-' * 10)

        for phase in ['train', 'valid']:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0
            optimizer.zero_grad()
            y=0

            for i, (inputs, labels) in enumerate(dataloaders[phase]):
                inputs, labels = inputs.to(device), labels.to(device)
                print(f"Epoch {epoch}/{num_epochs - 1}"+"-iterating-"+phase+str(y))
                y=y+1

                with autocast():
                    outputs = model(inputs)
                    loss = criterion(outputs, labels) / accumulation_steps

                if phase == 'train':
                    scaler.scale(loss).backward()

                    if (i + 1) % accumulation_steps == 0:
                        scaler.step(optimizer)
                        scaler.update()
                        optimizer.zero_grad()

                running_loss += loss.item() * inputs.size(0) * accumulation_steps
                _, preds = torch.max(outputs, 1)
                running_corrects += torch.sum(preds == labels.data)

                # Free up memory
                del inputs, labels, outputs
                torch.cuda.empty_cache()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print(f"{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}")
            logger.info(f"{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}")

            if phase == 'valid' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = model.state_dict()

        scheduler.step()
        print()

    time_elapsed = time.time() - since
    print(f"Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s")
    print(f"Best val Acc: {best_acc:.4f}")
    logger.info(f"Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s")
    logger.info(f"Best val Acc: {best_acc:.4f}")


    return model

# %%
# Train the model
model = train_model(model, criterion, optimizer, scheduler,dataloaders,dataset_sizes,device, num_epochs=25)

# Saving the model
os.makedirs('drive/MyDrive/plant_disease_detection/models', exist_ok=True)
torch.save(model.state_dict(), 'drive/MyDrive/plant_disease_detection/models/efficientnet_v2_S_nightshade_plant_disease_detection_model.pth')
print("Model saved successfully.")
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 15/24-iterating-valid83
# Epoch 15/24-iterating-valid84
# Epoch 15/24-iterating-valid85
# Epoch 15/24-iterating-valid86
# Epoch 15/24-iterating-valid87
# Epoch 15/24-iterating-valid88
# Epoch 15/24-iterating-valid89
# Epoch 15/24-iterating-valid90
# Epoch 15/24-iterating-valid91
# Epoch 15/24-iterating-valid92
# Epoch 15/24-iterating-valid93
# Epoch 15/24-iterating-valid94
# Epoch 15/24-iterating-valid95
# Epoch 15/24-iterating-valid96
# Epoch 15/24-iterating-valid97
# Epoch 15/24-iterating-valid98
# Epoch 15/24-iterating-valid99
# Epoch 15/24-iterating-valid100
# Epoch 15/24-iterating-valid101
# Epoch 15/24-iterating-valid102
# Epoch 15/24-iterating-valid103
# Epoch 15/24-iterating-valid104
# Epoch 15/24-iterating-valid105
# Epoch 15/24-iterating-valid106
# Epoch 15/24-iterating-valid107
# Epoch 15/24-iterating-valid108
# Epoch 15/24-iterating-valid109
# valid Loss: 0.0062 Acc: 0.9989
#
# Epoch 16/24
# ----------
# Epoch 16/24-iterating-train0
# Epoch 16/24-iterating-train1
# Epoch 16/24-iterating-train2
# Epoch 16/24-iterating-train3
# Epoch 16/24-iterating-train4
# Epoch 16/24-iterating-train5
# Epoch 16/24-iterating-train6
# Epoch 16/24-iterating-train7
# Epoch 16/24-iterating-train8
# Epoch 16/24-iterating-train9
# Epoch 16/24-iterating-train10
# Epoch 16/24-iterating-train11
# Epoch 16/24-iterating-train12
# Epoch 16/24-iterating-train13
# Epoch 16/24-iterating-train14
# Epoch 16/24-iterating-train15
# Epoch 16/24-iterating-train16
# Epoch 16/24-iterating-train17
# Epoch 16/24-iterating-train18
# Epoch 16/24-iterating-train19
# Epoch 16/24-iterating-train20
# Epoch 16/24-iterating-train21
# Epoch 16/24-iterating-train22
# Epoch 16/24-iterating-train23
# Epoch 16/24-iterating-train24
# Epoch 16/24-iterating-train25
# Epoch 16/24-iterating-train26
# Epoch 16/24-iterating-train27
# Epoch 16/24-iterating-train28
# Epoch 16/24-iterating-train29
# Epoch 16/24-iterating-train30
# Epoch 16/24-iterating-train31
# Epoch 16/24-iterating-train32
# Epoch 16/24-iterating-train33
# Epoch 16/24-iterating-train34
# Epoch 16/24-iterating-train35
# Epoch 16/24-iterating-train36
# Epoch 16/24-iterating-train37
# Epoch 16/24-iterating-train38
# Epoch 16/24-iterating-train39
# Epoch 16/24-iterating-train40
# Epoch 16/24-iterating-train41
# Epoch 16/24-iterating-train42
# Epoch 16/24-iterating-train43
# Epoch 16/24-iterating-train44
# Epoch 16/24-iterating-train45
# Epoch 16/24-iterating-train46
# Epoch 16/24-iterating-train47
# Epoch 16/24-iterating-train48
# Epoch 16/24-iterating-train49
# Epoch 16/24-iterating-train50
# Epoch 16/24-iterating-train51
# Epoch 16/24-iterating-train52
# Epoch 16/24-iterating-train53
# Epoch 16/24-iterating-train54
# Epoch 16/24-iterating-train55
# Epoch 16/24-iterating-train56
# Epoch 16/24-iterating-train57
# Epoch 16/24-iterating-train58
# Epoch 16/24-iterating-train59
# Epoch 16/24-iterating-train60
# Epoch 16/24-iterating-train61
# Epoch 16/24-iterating-train62
# Epoch 16/24-iterating-train63
# Epoch 16/24-iterating-train64
# Epoch 16/24-iterating-train65
# Epoch 16/24-iterating-train66
# Epoch 16/24-iterating-train67
# Epoch 16/24-iterating-train68
# Epoch 16/24-iterating-train69
# Epoch 16/24-iterating-train70
# Epoch 16/24-iterating-train71
# Epoch 16/24-iterating-train72
# Epoch 16/24-iterating-train73
# Epoch 16/24-iterating-train74
# Epoch 16/24-iterating-train75
# Epoch 16/24-iterating-train76
# Epoch 16/24-iterating-train77
# Epoch 16/24-iterating-train78
# Epoch 16/24-iterating-train79
# Epoch 16/24-iterating-train80
# Epoch 16/24-iterating-train81
# Epoch 16/24-iterating-train82
# Epoch 16/24-iterating-train83
# Epoch 16/24-iterating-train84
# Epoch 16/24-iterating-train85
# Epoch 16/24-iterating-train86
# Epoch 16/24-iterating-train87
# Epoch 16/24-iterating-train88
# Epoch 16/24-iterating-train89
# Epoch 16/24-iterating-train90
# Epoch 16/24-iterating-train91
# Epoch 16/24-iterating-train92
# Epoch 16/24-iterating-train93
# Epoch 16/24-iterating-train94
# Epoch 16/24-iterating-train95
# Epoch 16/24-iterating-train96
# Epoch 16/24-iterating-train97
# Epoch 16/24-iterating-train98
# Epoch 16/24-iterating-train99
# Epoch 16/24-iterating-train100
# Epoch 16/24-iterating-train101
# Epoch 16/24-iterating-train102
# Epoch 16/24-iterating-train103
# Epoch 16/24-iterating-train104
# Epoch 16/24-iterating-train105
# Epoch 16/24-iterating-train106
# Epoch 16/24-iterating-train107
# Epoch 16/24-iterating-train108
# Epoch 16/24-iterating-train109
# Epoch 16/24-iterating-train110
# Epoch 16/24-iterating-train111
# Epoch 16/24-iterating-train112
# Epoch 16/24-iterating-train113
# Epoch 16/24-iterating-train114
# Epoch 16/24-iterating-train115
# Epoch 16/24-iterating-train116
# Epoch 16/24-iterating-train117
# Epoch 16/24-iterating-train118
# Epoch 16/24-iterating-train119
# Epoch 16/24-iterating-train120
# Epoch 16/24-iterating-train121
# Epoch 16/24-iterating-train122
# Epoch 16/24-iterating-train123
# Epoch 16/24-iterating-train124
# Epoch 16/24-iterating-train125
# Epoch 16/24-iterating-train126
# Epoch 16/24-iterating-train127
# Epoch 16/24-iterating-train128
# Epoch 16/24-iterating-train129
# Epoch 16/24-iterating-train130
# Epoch 16/24-iterating-train131
# Epoch 16/24-iterating-train132
# Epoch 16/24-iterating-train133
# Epoch 16/24-iterating-train134
# Epoch 16/24-iterating-train135
# Epoch 16/24-iterating-train136
# Epoch 16/24-iterating-train137
# Epoch 16/24-iterating-train138
# Epoch 16/24-iterating-train139
# Epoch 16/24-iterating-train140
# Epoch 16/24-iterating-train141
# Epoch 16/24-iterating-train142
# Epoch 16/24-iterating-train143
# Epoch 16/24-iterating-train144
# Epoch 16/24-iterating-train145
# Epoch 16/24-iterating-train146
# Epoch 16/24-iterating-train147
# Epoch 16/24-iterating-train148
# Epoch 16/24-iterating-train149
# Epoch 16/24-iterating-train150
# Epoch 16/24-iterating-train151
# Epoch 16/24-iterating-train152
# Epoch 16/24-iterating-train153
# Epoch 16/24-iterating-train154
# Epoch 16/24-iterating-train155
# Epoch 16/24-iterating-train156
# Epoch 16/24-iterating-train157
# Epoch 16/24-iterating-train158
# Epoch 16/24-iterating-train159
# Epoch 16/24-iterating-train160
# Epoch 16/24-iterating-train161
# Epoch 16/24-iterating-train162
# Epoch 16/24-iterating-train163
# Epoch 16/24-iterating-train164
# Epoch 16/24-iterating-train165
# Epoch 16/24-iterating-train166
# Epoch 16/24-iterating-train167
# Epoch 16/24-iterating-train168
# Epoch 16/24-iterating-train169
# Epoch 16/24-iterating-train170
# Epoch 16/24-iterating-train171
# Epoch 16/24-iterating-train172
# Epoch 16/24-iterating-train173
# Epoch 16/24-iterating-train174
# Epoch 16/24-iterating-train175
# Epoch 16/24-iterating-train176
# Epoch 16/24-iterating-train177
# Epoch 16/24-iterating-train178
# Epoch 16/24-iterating-train179
# Epoch 16/24-iterating-train180
# Epoch 16/24-iterating-train181
# Epoch 16/24-iterating-train182
# Epoch 16/24-iterating-train183
# Epoch 16/24-iterating-train184
# Epoch 16/24-iterating-train185
# Epoch 16/24-iterating-train186
# Epoch 16/24-iterating-train187
# Epoch 16/24-iterating-train188
# Epoch 16/24-iterating-train189
# Epoch 16/24-iterating-train190
# Epoch 16/24-iterating-train191
# Epoch 16/24-iterating-train192
# Epoch 16/24-iterating-train193
# Epoch 16/24-iterating-train194
# Epoch 16/24-iterating-train195
# Epoch 16/24-iterating-train196
# Epoch 16/24-iterating-train197
# Epoch 16/24-iterating-train198
# Epoch 16/24-iterating-train199
# Epoch 16/24-iterating-train200
# Epoch 16/24-iterating-train201
# Epoch 16/24-iterating-train202
# Epoch 16/24-iterating-train203
# Epoch 16/24-iterating-train204
# Epoch 16/24-iterating-train205
# Epoch 16/24-iterating-train206
# Epoch 16/24-iterating-train207
# Epoch 16/24-iterating-train208
# Epoch 16/24-iterating-train209
# Epoch 16/24-iterating-train210
# Epoch 16/24-iterating-train211
# Epoch 16/24-iterating-train212
# Epoch 16/24-iterating-train213
# Epoch 16/24-iterating-train214
# Epoch 16/24-iterating-train215
# Epoch 16/24-iterating-train216
# Epoch 16/24-iterating-train217
# Epoch 16/24-iterating-train218
# Epoch 16/24-iterating-train219
# Epoch 16/24-iterating-train220
# Epoch 16/24-iterating-train221
# Epoch 16/24-iterating-train222
# Epoch 16/24-iterating-train223
# Epoch 16/24-iterating-train224
# Epoch 16/24-iterating-train225
# Epoch 16/24-iterating-train226
# Epoch 16/24-iterating-train227
# Epoch 16/24-iterating-train228
# Epoch 16/24-iterating-train229
# Epoch 16/24-iterating-train230
# Epoch 16/24-iterating-train231
# Epoch 16/24-iterating-train232
# Epoch 16/24-iterating-train233
# Epoch 16/24-iterating-train234
# Epoch 16/24-iterating-train235
# Epoch 16/24-iterating-train236
# Epoch 16/24-iterating-train237
# Epoch 16/24-iterating-train238
# Epoch 16/24-iterating-train239
# Epoch 16/24-iterating-train240
# Epoch 16/24-iterating-train241
# Epoch 16/24-iterating-train242
# Epoch 16/24-iterating-train243
# Epoch 16/24-iterating-train244
# Epoch 16/24-iterating-train245
# Epoch 16/24-iterating-train246
# Epoch 16/24-iterating-train247
# Epoch 16/24-iterating-train248
# Epoch 16/24-iterating-train249
# Epoch 16/24-iterating-train250
# Epoch 16/24-iterating-train251
# Epoch 16/24-iterating-train252
# Epoch 16/24-iterating-train253
# Epoch 16/24-iterating-train254
# Epoch 16/24-iterating-train255
# Epoch 16/24-iterating-train256
# Epoch 16/24-iterating-train257
# Epoch 16/24-iterating-train258
# Epoch 16/24-iterating-train259
# Epoch 16/24-iterating-train260
# Epoch 16/24-iterating-train261
# Epoch 16/24-iterating-train262
# Epoch 16/24-iterating-train263
# Epoch 16/24-iterating-train264
# Epoch 16/24-iterating-train265
# Epoch 16/24-iterating-train266
# Epoch 16/24-iterating-train267
# Epoch 16/24-iterating-train268
# Epoch 16/24-iterating-train269
# Epoch 16/24-iterating-train270
# Epoch 16/24-iterating-train271
# Epoch 16/24-iterating-train272
# Epoch 16/24-iterating-train273
# Epoch 16/24-iterating-train274
# Epoch 16/24-iterating-train275
# Epoch 16/24-iterating-train276
# Epoch 16/24-iterating-train277
# Epoch 16/24-iterating-train278
# Epoch 16/24-iterating-train279
# Epoch 16/24-iterating-train280
# Epoch 16/24-iterating-train281
# Epoch 16/24-iterating-train282
# Epoch 16/24-iterating-train283
# Epoch 16/24-iterating-train284
# Epoch 16/24-iterating-train285
# Epoch 16/24-iterating-train286
# Epoch 16/24-iterating-train287
# Epoch 16/24-iterating-train288
# Epoch 16/24-iterating-train289
# Epoch 16/24-iterating-train290
# Epoch 16/24-iterating-train291
# Epoch 16/24-iterating-train292
# Epoch 16/24-iterating-train293
# Epoch 16/24-iterating-train294
# Epoch 16/24-iterating-train295
# Epoch 16/24-iterating-train296
# Epoch 16/24-iterating-train297
# Epoch 16/24-iterating-train298
# Epoch 16/24-iterating-train299
# Epoch 16/24-iterating-train300
# Epoch 16/24-iterating-train301
# Epoch 16/24-iterating-train302
# Epoch 16/24-iterating-train303
# Epoch 16/24-iterating-train304
# Epoch 16/24-iterating-train305
# Epoch 16/24-iterating-train306
# Epoch 16/24-iterating-train307
# Epoch 16/24-iterating-train308
# Epoch 16/24-iterating-train309
# Epoch 16/24-iterating-train310
# Epoch 16/24-iterating-train311
# Epoch 16/24-iterating-train312
# Epoch 16/24-iterating-train313
# Epoch 16/24-iterating-train314
# Epoch 16/24-iterating-train315
# Epoch 16/24-iterating-train316
# Epoch 16/24-iterating-train317
# Epoch 16/24-iterating-train318
# Epoch 16/24-iterating-train319
# Epoch 16/24-iterating-train320
# Epoch 16/24-iterating-train321
# Epoch 16/24-iterating-train322
# Epoch 16/24-iterating-train323
# Epoch 16/24-iterating-train324
# Epoch 16/24-iterating-train325
# Epoch 16/24-iterating-train326
# Epoch 16/24-iterating-train327
# Epoch 16/24-iterating-train328
# Epoch 16/24-iterating-train329
# Epoch 16/24-iterating-train330
# Epoch 16/24-iterating-train331
# Epoch 16/24-iterating-train332
# Epoch 16/24-iterating-train333
# Epoch 16/24-iterating-train334
# Epoch 16/24-iterating-train335
# Epoch 16/24-iterating-train336
# Epoch 16/24-iterating-train337
# Epoch 16/24-iterating-train338
# Epoch 16/24-iterating-train339
# Epoch 16/24-iterating-train340
# Epoch 16/24-iterating-train341
# Epoch 16/24-iterating-train342
# Epoch 16/24-iterating-train343
# Epoch 16/24-iterating-train344
# Epoch 16/24-iterating-train345
# Epoch 16/24-iterating-train346
# Epoch 16/24-iterating-train347
# Epoch 16/24-iterating-train348
# Epoch 16/24-iterating-train349
# Epoch 16/24-iterating-train350
# Epoch 16/24-iterating-train351
# Epoch 16/24-iterating-train352
# Epoch 16/24-iterating-train353
# Epoch 16/24-iterating-train354
# Epoch 16/24-iterating-train355
# Epoch 16/24-iterating-train356
# Epoch 16/24-iterating-train357
# Epoch 16/24-iterating-train358
# Epoch 16/24-iterating-train359
# Epoch 16/24-iterating-train360
# Epoch 16/24-iterating-train361
# Epoch 16/24-iterating-train362
# Epoch 16/24-iterating-train363
# Epoch 16/24-iterating-train364
# Epoch 16/24-iterating-train365
# Epoch 16/24-iterating-train366
# Epoch 16/24-iterating-train367
# Epoch 16/24-iterating-train368
# Epoch 16/24-iterating-train369
# Epoch 16/24-iterating-train370
# Epoch 16/24-iterating-train371
# Epoch 16/24-iterating-train372
# Epoch 16/24-iterating-train373
# Epoch 16/24-iterating-train374
# Epoch 16/24-iterating-train375
# Epoch 16/24-iterating-train376
# Epoch 16/24-iterating-train377
# Epoch 16/24-iterating-train378
# Epoch 16/24-iterating-train379
# Epoch 16/24-iterating-train380
# Epoch 16/24-iterating-train381
# Epoch 16/24-iterating-train382
# Epoch 16/24-iterating-train383
# Epoch 16/24-iterating-train384
# Epoch 16/24-iterating-train385
# Epoch 16/24-iterating-train386
# Epoch 16/24-iterating-train387
# Epoch 16/24-iterating-train388
# Epoch 16/24-iterating-train389
# Epoch 16/24-iterating-train390
# Epoch 16/24-iterating-train391
# Epoch 16/24-iterating-train392
# Epoch 16/24-iterating-train393
# Epoch 16/24-iterating-train394
# Epoch 16/24-iterating-train395
# Epoch 16/24-iterating-train396
# Epoch 16/24-iterating-train397
# Epoch 16/24-iterating-train398
# Epoch 16/24-iterating-train399
# Epoch 16/24-iterating-train400
# Epoch 16/24-iterating-train401
# Epoch 16/24-iterating-train402
# Epoch 16/24-iterating-train403
# Epoch 16/24-iterating-train404
# Epoch 16/24-iterating-train405
# Epoch 16/24-iterating-train406
# Epoch 16/24-iterating-train407
# Epoch 16/24-iterating-train408
# Epoch 16/24-iterating-train409
# Epoch 16/24-iterating-train410
# Epoch 16/24-iterating-train411
# Epoch 16/24-iterating-train412
# Epoch 16/24-iterating-train413
# Epoch 16/24-iterating-train414
# Epoch 16/24-iterating-train415
# Epoch 16/24-iterating-train416
# Epoch 16/24-iterating-train417
# Epoch 16/24-iterating-train418
# Epoch 16/24-iterating-train419
# Epoch 16/24-iterating-train420
# Epoch 16/24-iterating-train421
# Epoch 16/24-iterating-train422
# Epoch 16/24-iterating-train423
# Epoch 16/24-iterating-train424
# Epoch 16/24-iterating-train425
# Epoch 16/24-iterating-train426
# Epoch 16/24-iterating-train427
# Epoch 16/24-iterating-train428
# Epoch 16/24-iterating-train429
# Epoch 16/24-iterating-train430
# Epoch 16/24-iterating-train431
# Epoch 16/24-iterating-train432
# Epoch 16/24-iterating-train433
# Epoch 16/24-iterating-train434
# Epoch 16/24-iterating-train435
# Epoch 16/24-iterating-train436
# train Loss: 0.0363 Acc: 0.9872
# Epoch 16/24-iterating-valid0
# Epoch 16/24-iterating-valid1
# Epoch 16/24-iterating-valid2
# Epoch 16/24-iterating-valid3
# Epoch 16/24-iterating-valid4
# Epoch 16/24-iterating-valid5
# Epoch 16/24-iterating-valid6
# Epoch 16/24-iterating-valid7
# Epoch 16/24-iterating-valid8
# Epoch 16/24-iterating-valid9
# Epoch 16/24-iterating-valid10
# Epoch 16/24-iterating-valid11
# Epoch 16/24-iterating-valid12
# Epoch 16/24-iterating-valid13
# Epoch 16/24-iterating-valid14
# Epoch 16/24-iterating-valid15
# Epoch 16/24-iterating-valid16
# Epoch 16/24-iterating-valid17
# Epoch 16/24-iterating-valid18
# Epoch 16/24-iterating-valid19
# Epoch 16/24-iterating-valid20
# Epoch 16/24-iterating-valid21
# Epoch 16/24-iterating-valid22
# Epoch 16/24-iterating-valid23
# Epoch 16/24-iterating-valid24
# Epoch 16/24-iterating-valid25
# Epoch 16/24-iterating-valid26
# Epoch 16/24-iterating-valid27
# Epoch 16/24-iterating-valid28
# Epoch 16/24-iterating-valid29
# Epoch 16/24-iterating-valid30
# Epoch 16/24-iterating-valid31
# Epoch 16/24-iterating-valid32
# Epoch 16/24-iterating-valid33
# Epoch 16/24-iterating-valid34
# Epoch 16/24-iterating-valid35
# Epoch 16/24-iterating-valid36
# Epoch 16/24-iterating-valid37
# Epoch 16/24-iterating-valid38
# Epoch 16/24-iterating-valid39
# Epoch 16/24-iterating-valid40
# Epoch 16/24-iterating-valid41
# Epoch 16/24-iterating-valid42
# Epoch 16/24-iterating-valid43
# Epoch 16/24-iterating-valid44
# Epoch 16/24-iterating-valid45
# Epoch 16/24-iterating-valid46
# Epoch 16/24-iterating-valid47
# Epoch 16/24-iterating-valid48
# Epoch 16/24-iterating-valid49
# Epoch 16/24-iterating-valid50
# Epoch 16/24-iterating-valid51
# Epoch 16/24-iterating-valid52
# Epoch 16/24-iterating-valid53
# Epoch 16/24-iterating-valid54
# Epoch 16/24-iterating-valid55
# Epoch 16/24-iterating-valid56
# Epoch 16/24-iterating-valid57
# Epoch 16/24-iterating-valid58
# Epoch 16/24-iterating-valid59
# Epoch 16/24-iterating-valid60
# Epoch 16/24-iterating-valid61
# Epoch 16/24-iterating-valid62
# Epoch 16/24-iterating-valid63
# Epoch 16/24-iterating-valid64
# Epoch 16/24-iterating-valid65
# Epoch 16/24-iterating-valid66
# Epoch 16/24-iterating-valid67
# Epoch 16/24-iterating-valid68
# Epoch 16/24-iterating-valid69
# Epoch 16/24-iterating-valid70
# Epoch 16/24-iterating-valid71
# Epoch 16/24-iterating-valid72
# Epoch 16/24-iterating-valid73
# Epoch 16/24-iterating-valid74
# Epoch 16/24-iterating-valid75
# Epoch 16/24-iterating-valid76
# Epoch 16/24-iterating-valid77
# Epoch 16/24-iterating-valid78
# Epoch 16/24-iterating-valid79
# Epoch 16/24-iterating-valid80
# Epoch 16/24-iterating-valid81
# Epoch 16/24-iterating-valid82
# Epoch 16/24-iterating-valid83
# Epoch 16/24-iterating-valid84
# Epoch 16/24-iterating-valid85
# Epoch 16/24-iterating-valid86
# Epoch 16/24-iterating-valid87
# Epoch 16/24-iterating-valid88
# Epoch 16/24-iterating-valid89
# Epoch 16/24-iterating-valid90
# Epoch 16/24-iterating-valid91
# Epoch 16/24-iterating-valid92
# Epoch 16/24-iterating-valid93
# Epoch 16/24-iterating-valid94
# Epoch 16/24-iterating-valid95
# Epoch 16/24-iterating-valid96
# Epoch 16/24-iterating-valid97
# Epoch 16/24-iterating-valid98
# Epoch 16/24-iterating-valid99
# Epoch 16/24-iterating-valid100
# Epoch 16/24-iterating-valid101
# Epoch 16/24-iterating-valid102
# Epoch 16/24-iterating-valid103
# Epoch 16/24-iterating-valid104
# Epoch 16/24-iterating-valid105
# Epoch 16/24-iterating-valid106
# Epoch 16/24-iterating-valid107
# Epoch 16/24-iterating-valid108
# Epoch 16/24-iterating-valid109
# valid Loss: 0.0052 Acc: 0.9990
#
# Epoch 17/24
# ----------
# Epoch 17/24-iterating-train0
# Epoch 17/24-iterating-train1
# Epoch 17/24-iterating-train2
# Epoch 17/24-iterating-train3
# Epoch 17/24-iterating-train4
# Epoch 17/24-iterating-train5
# Epoch 17/24-iterating-train6
# Epoch 17/24-iterating-train7
# Epoch 17/24-iterating-train8
# Epoch 17/24-iterating-train9
# Epoch 17/24-iterating-train10
# Epoch 17/24-iterating-train11
# Epoch 17/24-iterating-train12
# Epoch 17/24-iterating-train13
# Epoch 17/24-iterating-train14
# Epoch 17/24-iterating-train15
# Epoch 17/24-iterating-train16
# Epoch 17/24-iterating-train17
# Epoch 17/24-iterating-train18
# Epoch 17/24-iterating-train19
# Epoch 17/24-iterating-train20
# Epoch 17/24-iterating-train21
# Epoch 17/24-iterating-train22
# Epoch 17/24-iterating-train23
# Epoch 17/24-iterating-train24
# Epoch 17/24-iterating-train25
# Epoch 17/24-iterating-train26
# Epoch 17/24-iterating-train27
# Epoch 17/24-iterating-train28
# Epoch 17/24-iterating-train29
# Epoch 17/24-iterating-train30
# Epoch 17/24-iterating-train31
# Epoch 17/24-iterating-train32
# Epoch 17/24-iterating-train33
# Epoch 17/24-iterating-train34
# Epoch 17/24-iterating-train35
# Epoch 17/24-iterating-train36
# Epoch 17/24-iterating-train37
# Epoch 17/24-iterating-train38
# Epoch 17/24-iterating-train39
# Epoch 17/24-iterating-train40
# Epoch 17/24-iterating-train41
# Epoch 17/24-iterating-train42
# Epoch 17/24-iterating-train43
# Epoch 17/24-iterating-train44
# Epoch 17/24-iterating-train45
# Epoch 17/24-iterating-train46
# Epoch 17/24-iterating-train47
# Epoch 17/24-iterating-train48
# Epoch 17/24-iterating-train49
# Epoch 17/24-iterating-train50
# Epoch 17/24-iterating-train51
# Epoch 17/24-iterating-train52
# Epoch 17/24-iterating-train53
# Epoch 17/24-iterating-train54
# Epoch 17/24-iterating-train55
# Epoch 17/24-iterating-train56
# Epoch 17/24-iterating-train57
# Epoch 17/24-iterating-train58
# Epoch 17/24-iterating-train59
# Epoch 17/24-iterating-train60
# Epoch 17/24-iterating-train61
# Epoch 17/24-iterating-train62
# Epoch 17/24-iterating-train63
# Epoch 17/24-iterating-train64
# Epoch 17/24-iterating-train65
# Epoch 17/24-iterating-train66
# Epoch 17/24-iterating-train67
# Epoch 17/24-iterating-train68
# Epoch 17/24-iterating-train69
# Epoch 17/24-iterating-train70
# Epoch 17/24-iterating-train71
# Epoch 17/24-iterating-train72
# Epoch 17/24-iterating-train73
# Epoch 17/24-iterating-train74
# Epoch 17/24-iterating-train75
# Epoch 17/24-iterating-train76
# Epoch 17/24-iterating-train77
# Epoch 17/24-iterating-train78
# Epoch 17/24-iterating-train79
# Epoch 17/24-iterating-train80
# Epoch 17/24-iterating-train81
# Epoch 17/24-iterating-train82
# Epoch 17/24-iterating-train83
# Epoch 17/24-iterating-train84
# Epoch 17/24-iterating-train85
# Epoch 17/24-iterating-train86
# Epoch 17/24-iterating-train87
# Epoch 17/24-iterating-train88
# Epoch 17/24-iterating-train89
# Epoch 17/24-iterating-train90
# Epoch 17/24-iterating-train91
# Epoch 17/24-iterating-train92
# Epoch 17/24-iterating-train93
# Epoch 17/24-iterating-train94
# Epoch 17/24-iterating-train95
# Epoch 17/24-iterating-train96
# Epoch 17/24-iterating-train97
# Epoch 17/24-iterating-train98
# Epoch 17/24-iterating-train99
# Epoch 17/24-iterating-train100
# Epoch 17/24-iterating-train101
# Epoch 17/24-iterating-train102
# Epoch 17/24-iterating-train103
# Epoch 17/24-iterating-train104
# Epoch 17/24-iterating-train105
# Epoch 17/24-iterating-train106
# Epoch 17/24-iterating-train107
# Epoch 17/24-iterating-train108
# Epoch 17/24-iterating-train109
# Epoch 17/24-iterating-train110
# Epoch 17/24-iterating-train111
# Epoch 17/24-iterating-train112
# Epoch 17/24-iterating-train113
# Epoch 17/24-iterating-train114
# Epoch 17/24-iterating-train115
# Epoch 17/24-iterating-train116
# Epoch 17/24-iterating-train117
# Epoch 17/24-iterating-train118
# Epoch 17/24-iterating-train119
# Epoch 17/24-iterating-train120
# Epoch 17/24-iterating-train121
# Epoch 17/24-iterating-train122
# Epoch 17/24-iterating-train123
# Epoch 17/24-iterating-train124
# Epoch 17/24-iterating-train125
# Epoch 17/24-iterating-train126
# Epoch 17/24-iterating-train127
# Epoch 17/24-iterating-train128
# Epoch 17/24-iterating-train129
# Epoch 17/24-iterating-train130
# Epoch 17/24-iterating-train131
# Epoch 17/24-iterating-train132
# Epoch 17/24-iterating-train133
# Epoch 17/24-iterating-train134
# Epoch 17/24-iterating-train135
# Epoch 17/24-iterating-train136
# Epoch 17/24-iterating-train137
# Epoch 17/24-iterating-train138
# Epoch 17/24-iterating-train139
# Epoch 17/24-iterating-train140
# Epoch 17/24-iterating-train141
# Epoch 17/24-iterating-train142
# Epoch 17/24-iterating-train143
# Epoch 17/24-iterating-train144
# Epoch 17/24-iterating-train145
# Epoch 17/24-iterating-train146
# Epoch 17/24-iterating-train147
# Epoch 17/24-iterating-train148
# Epoch 17/24-iterating-train149
# Epoch 17/24-iterating-train150
# Epoch 17/24-iterating-train151
# Epoch 17/24-iterating-train152
# Epoch 17/24-iterating-train153
# Epoch 17/24-iterating-train154
# Epoch 17/24-iterating-train155
# Epoch 17/24-iterating-train156
# Epoch 17/24-iterating-train157
# Epoch 17/24-iterating-train158
# Epoch 17/24-iterating-train159
# Epoch 17/24-iterating-train160
# Epoch 17/24-iterating-train161
# Epoch 17/24-iterating-train162
# Epoch 17/24-iterating-train163
# Epoch 17/24-iterating-train164
# Epoch 17/24-iterating-train165
# Epoch 17/24-iterating-train166
# Epoch 17/24-iterating-train167
# Epoch 17/24-iterating-train168
# Epoch 17/24-iterating-train169
# Epoch 17/24-iterating-train170
# Epoch 17/24-iterating-train171
# Epoch 17/24-iterating-train172
# Epoch 17/24-iterating-train173
# Epoch 17/24-iterating-train174
# Epoch 17/24-iterating-train175
# Epoch 17/24-iterating-train176
# Epoch 17/24-iterating-train177
# Epoch 17/24-iterating-train178
# Epoch 17/24-iterating-train179
# Epoch 17/24-iterating-train180
# Epoch 17/24-iterating-train181
# Epoch 17/24-iterating-train182
# Epoch 17/24-iterating-train183
# Epoch 17/24-iterating-train184
# Epoch 17/24-iterating-train185
# Epoch 17/24-iterating-train186
# Epoch 17/24-iterating-train187
# Epoch 17/24-iterating-train188
# Epoch 17/24-iterating-train189
# Epoch 17/24-iterating-train190
# Epoch 17/24-iterating-train191
# Epoch 17/24-iterating-train192
# Epoch 17/24-iterating-train193
# Epoch 17/24-iterating-train194
# Epoch 17/24-iterating-train195
# Epoch 17/24-iterating-train196
# Epoch 17/24-iterating-train197
# Epoch 17/24-iterating-train198
# Epoch 17/24-iterating-train199
# Epoch 17/24-iterating-train200
# Epoch 17/24-iterating-train201
# Epoch 17/24-iterating-train202
# Epoch 17/24-iterating-train203
# Epoch 17/24-iterating-train204
# Epoch 17/24-iterating-train205
# Epoch 17/24-iterating-train206
# Epoch 17/24-iterating-train207
# Epoch 17/24-iterating-train208
# Epoch 17/24-iterating-train209
# Epoch 17/24-iterating-train210
# Epoch 17/24-iterating-train211
# Epoch 17/24-iterating-train212
# Epoch 17/24-iterating-train213
# Epoch 17/24-iterating-train214
# Epoch 17/24-iterating-train215
# Epoch 17/24-iterating-train216
# Epoch 17/24-iterating-train217
# Epoch 17/24-iterating-train218
# Epoch 17/24-iterating-train219
# Epoch 17/24-iterating-train220
# Epoch 17/24-iterating-train221
# Epoch 17/24-iterating-train222
# Epoch 17/24-iterating-train223
# Epoch 17/24-iterating-train224
# Epoch 17/24-iterating-train225
# Epoch 17/24-iterating-train226
# Epoch 17/24-iterating-train227
# Epoch 17/24-iterating-train228
# Epoch 17/24-iterating-train229
# Epoch 17/24-iterating-train230
# Epoch 17/24-iterating-train231
# Epoch 17/24-iterating-train232
# Epoch 17/24-iterating-train233
# Epoch 17/24-iterating-train234
# Epoch 17/24-iterating-train235
# Epoch 17/24-iterating-train236
# Epoch 17/24-iterating-train237
# Epoch 17/24-iterating-train238
# Epoch 17/24-iterating-train239
# Epoch 17/24-iterating-train240
# Epoch 17/24-iterating-train241
# Epoch 17/24-iterating-train242
# Epoch 17/24-iterating-train243
# Epoch 17/24-iterating-train244
# Epoch 17/24-iterating-train245
# Epoch 17/24-iterating-train246
# Epoch 17/24-iterating-train247
# Epoch 17/24-iterating-train248
# Epoch 17/24-iterating-train249
# Epoch 17/24-iterating-train250
# Epoch 17/24-iterating-train251
# Epoch 17/24-iterating-train252
# Epoch 17/24-iterating-train253
# Epoch 17/24-iterating-train254
# Epoch 17/24-iterating-train255
# Epoch 17/24-iterating-train256
# Epoch 17/24-iterating-train257
# Epoch 17/24-iterating-train258
# Epoch 17/24-iterating-train259
# Epoch 17/24-iterating-train260
# Epoch 17/24-iterating-train261
# Epoch 17/24-iterating-train262
# Epoch 17/24-iterating-train263
# Epoch 17/24-iterating-train264
# Epoch 17/24-iterating-train265
# Epoch 17/24-iterating-train266
# Epoch 17/24-iterating-train267
# Epoch 17/24-iterating-train268
# Epoch 17/24-iterating-train269
# Epoch 17/24-iterating-train270
# Epoch 17/24-iterating-train271
# Epoch 17/24-iterating-train272
# Epoch 17/24-iterating-train273
# Epoch 17/24-iterating-train274
# Epoch 17/24-iterating-train275
# Epoch 17/24-iterating-train276
# Epoch 17/24-iterating-train277
# Epoch 17/24-iterating-train278
# Epoch 17/24-iterating-train279
# Epoch 17/24-iterating-train280
# Epoch 17/24-iterating-train281
# Epoch 17/24-iterating-train282
# Epoch 17/24-iterating-train283
# Epoch 17/24-iterating-train284
# Epoch 17/24-iterating-train285
# Epoch 17/24-iterating-train286
# Epoch 17/24-iterating-train287
# Epoch 17/24-iterating-train288
# Epoch 17/24-iterating-train289
# Epoch 17/24-iterating-train290
# Epoch 17/24-iterating-train291
# Epoch 17/24-iterating-train292
# Epoch 17/24-iterating-train293
# Epoch 17/24-iterating-train294
# Epoch 17/24-iterating-train295
# Epoch 17/24-iterating-train296
# Epoch 17/24-iterating-train297
# Epoch 17/24-iterating-train298
# Epoch 17/24-iterating-train299
# Epoch 17/24-iterating-train300
# Epoch 17/24-iterating-train301
# Epoch 17/24-iterating-train302
# Epoch 17/24-iterating-train303
# Epoch 17/24-iterating-train304
# Epoch 17/24-iterating-train305
# Epoch 17/24-iterating-train306
# Epoch 17/24-iterating-train307
# Epoch 17/24-iterating-train308
# Epoch 17/24-iterating-train309
# Epoch 17/24-iterating-train310
# Epoch 17/24-iterating-train311
# Epoch 17/24-iterating-train312
# Epoch 17/24-iterating-train313
# Epoch 17/24-iterating-train314
# Epoch 17/24-iterating-train315
# Epoch 17/24-iterating-train316
# Epoch 17/24-iterating-train317
# Epoch 17/24-iterating-train318
# Epoch 17/24-iterating-train319
# Epoch 17/24-iterating-train320
# Epoch 17/24-iterating-train321
# Epoch 17/24-iterating-train322
# Epoch 17/24-iterating-train323
# Epoch 17/24-iterating-train324
# Epoch 17/24-iterating-train325
# Epoch 17/24-iterating-train326
# Epoch 17/24-iterating-train327
# Epoch 17/24-iterating-train328
# Epoch 17/24-iterating-train329
# Epoch 17/24-iterating-train330
# Epoch 17/24-iterating-train331
# Epoch 17/24-iterating-train332
# Epoch 17/24-iterating-train333
# Epoch 17/24-iterating-train334
# Epoch 17/24-iterating-train335
# Epoch 17/24-iterating-train336
# Epoch 17/24-iterating-train337
# Epoch 17/24-iterating-train338
# Epoch 17/24-iterating-train339
# Epoch 17/24-iterating-train340
# Epoch 17/24-iterating-train341
# Epoch 17/24-iterating-train342
# Epoch 17/24-iterating-train343
# Epoch 17/24-iterating-train344
# Epoch 17/24-iterating-train345
# Epoch 17/24-iterating-train346
# Epoch 17/24-iterating-train347
# Epoch 17/24-iterating-train348
# Epoch 17/24-iterating-train349
# Epoch 17/24-iterating-train350
# Epoch 17/24-iterating-train351
# Epoch 17/24-iterating-train352
# Epoch 17/24-iterating-train353
# Epoch 17/24-iterating-train354
# Epoch 17/24-iterating-train355
# Epoch 17/24-iterating-train356
# Epoch 17/24-iterating-train357
# Epoch 17/24-iterating-train358
# Epoch 17/24-iterating-train359
# Epoch 17/24-iterating-train360
# Epoch 17/24-iterating-train361
# Epoch 17/24-iterating-train362
# Epoch 17/24-iterating-train363
# Epoch 17/24-iterating-train364
# Epoch 17/24-iterating-train365
# Epoch 17/24-iterating-train366
# Epoch 17/24-iterating-train367
# Epoch 17/24-iterating-train368
# Epoch 17/24-iterating-train369
# Epoch 17/24-iterating-train370
# Epoch 17/24-iterating-train371
# Epoch 17/24-iterating-train372
# Epoch 17/24-iterating-train373
# Epoch 17/24-iterating-train374
# Epoch 17/24-iterating-train375
# Epoch 17/24-iterating-train376
# Epoch 17/24-iterating-train377
# Epoch 17/24-iterating-train378
# Epoch 17/24-iterating-train379
# Epoch 17/24-iterating-train380
# Epoch 17/24-iterating-train381
# Epoch 17/24-iterating-train382
# Epoch 17/24-iterating-train383
# Epoch 17/24-iterating-train384
# Epoch 17/24-iterating-train385
# Epoch 17/24-iterating-train386
# Epoch 17/24-iterating-train387
# Epoch 17/24-iterating-train388
# Epoch 17/24-iterating-train389
# Epoch 17/24-iterating-train390
# Epoch 17/24-iterating-train391
# Epoch 17/24-iterating-train392
# Epoch 17/24-iterating-train393
# Epoch 17/24-iterating-train394
# Epoch 17/24-iterating-train395
# Epoch 17/24-iterating-train396
# Epoch 17/24-iterating-train397
# Epoch 17/24-iterating-train398
# Epoch 17/24-iterating-train399
# Epoch 17/24-iterating-train400
# Epoch 17/24-iterating-train401
# Epoch 17/24-iterating-train402
# Epoch 17/24-iterating-train403
# Epoch 17/24-iterating-train404
# Epoch 17/24-iterating-train405
# Epoch 17/24-iterating-train406
# Epoch 17/24-iterating-train407
# Epoch 17/24-iterating-train408
# Epoch 17/24-iterating-train409
# Epoch 17/24-iterating-train410
# Epoch 17/24-iterating-train411
# Epoch 17/24-iterating-train412
# Epoch 17/24-iterating-train413
# Epoch 17/24-iterating-train414
# Epoch 17/24-iterating-train415
# Epoch 17/24-iterating-train416
# Epoch 17/24-iterating-train417
# Epoch 17/24-iterating-train418
# Epoch 17/24-iterating-train419
# Epoch 17/24-iterating-train420
# Epoch 17/24-iterating-train421
# Epoch 17/24-iterating-train422
# Epoch 17/24-iterating-train423
# Epoch 17/24-iterating-train424
# Epoch 17/24-iterating-train425
# Epoch 17/24-iterating-train426
# Epoch 17/24-iterating-train427
# Epoch 17/24-iterating-train428
# Epoch 17/24-iterating-train429
# Epoch 17/24-iterating-train430
# Epoch 17/24-iterating-train431
# Epoch 17/24-iterating-train432
# Epoch 17/24-iterating-train433
# Epoch 17/24-iterating-train434
# Epoch 17/24-iterating-train435
# Epoch 17/24-iterating-train436
# train Loss: 0.0335 Acc: 0.9891
# Epoch 17/24-iterating-valid0
# Epoch 17/24-iterating-valid1
# Epoch 17/24-iterating-valid2
# Epoch 17/24-iterating-valid3
# Epoch 17/24-iterating-valid4
# Epoch 17/24-iterating-valid5
# Epoch 17/24-iterating-valid6
# Epoch 17/24-iterating-valid7
# Epoch 17/24-iterating-valid8
# Epoch 17/24-iterating-valid9
# Epoch 17/24-iterating-valid10
# Epoch 17/24-iterating-valid11
# Epoch 17/24-iterating-valid12
# Epoch 17/24-iterating-valid13
# Epoch 17/24-iterating-valid14
# Epoch 17/24-iterating-valid15
# Epoch 17/24-iterating-valid16
# Epoch 17/24-iterating-valid17
# Epoch 17/24-iterating-valid18
# Epoch 17/24-iterating-valid19
# Epoch 17/24-iterating-valid20
# Epoch 17/24-iterating-valid21
# Epoch 17/24-iterating-valid22
# Epoch 17/24-iterating-valid23
# Epoch 17/24-iterating-valid24
# Epoch 17/24-iterating-valid25
# Epoch 17/24-iterating-valid26
# Epoch 17/24-iterating-valid27
# Epoch 17/24-iterating-valid28
# Epoch 17/24-iterating-valid29
# Epoch 17/24-iterating-valid30
# Epoch 17/24-iterating-valid31
# Epoch 17/24-iterating-valid32
# Epoch 17/24-iterating-valid33
# Epoch 17/24-iterating-valid34
# Epoch 17/24-iterating-valid35
# Epoch 17/24-iterating-valid36
# Epoch 17/24-iterating-valid37
# Epoch 17/24-iterating-valid38
# Epoch 17/24-iterating-valid39
# Epoch 17/24-iterating-valid40
# Epoch 17/24-iterating-valid41
# Epoch 17/24-iterating-valid42
# Epoch 17/24-iterating-valid43
# Epoch 17/24-iterating-valid44
# Epoch 17/24-iterating-valid45
# Epoch 17/24-iterating-valid46
# Epoch 17/24-iterating-valid47
# Epoch 17/24-iterating-valid48
# Epoch 17/24-iterating-valid49
# Epoch 17/24-iterating-valid50
# Epoch 17/24-iterating-valid51
# Epoch 17/24-iterating-valid52
# Epoch 17/24-iterating-valid53
# Epoch 17/24-iterating-valid54
# Epoch 17/24-iterating-valid55
# Epoch 17/24-iterating-valid56
# Epoch 17/24-iterating-valid57
# Epoch 17/24-iterating-valid58
# Epoch 17/24-iterating-valid59
# Epoch 17/24-iterating-valid60
# Epoch 17/24-iterating-valid61
# Epoch 17/24-iterating-valid62
# Epoch 17/24-iterating-valid63
# Epoch 17/24-iterating-valid64
# Epoch 17/24-iterating-valid65
# Epoch 17/24-iterating-valid66
# Epoch 17/24-iterating-valid67
# Epoch 17/24-iterating-valid68
# Epoch 17/24-iterating-valid69
# Epoch 17/24-iterating-valid70
# Epoch 17/24-iterating-valid71
# Epoch 17/24-iterating-valid72
# Epoch 17/24-iterating-valid73
# Epoch 17/24-iterating-valid74
# Epoch 17/24-iterating-valid75
# Epoch 17/24-iterating-valid76
# Epoch 17/24-iterating-valid77
# Epoch 17/24-iterating-valid78
# Epoch 17/24-iterating-valid79
# Epoch 17/24-iterating-valid80
# Epoch 17/24-iterating-valid81
# Epoch 17/24-iterating-valid82
# Epoch 17/24-iterating-valid83
# Epoch 17/24-iterating-valid84
# Epoch 17/24-iterating-valid85
# Epoch 17/24-iterating-valid86
# Epoch 17/24-iterating-valid87
# Epoch 17/24-iterating-valid88
# Epoch 17/24-iterating-valid89
# Epoch 17/24-iterating-valid90
# Epoch 17/24-iterating-valid91
# Epoch 17/24-iterating-valid92
# Epoch 17/24-iterating-valid93
# Epoch 17/24-iterating-valid94
# Epoch 17/24-iterating-valid95
# Epoch 17/24-iterating-valid96
# Epoch 17/24-iterating-valid97
# Epoch 17/24-iterating-valid98
# Epoch 17/24-iterating-valid99
# Epoch 17/24-iterating-valid100
# Epoch 17/24-iterating-valid101
# Epoch 17/24-iterating-valid102
# Epoch 17/24-iterating-valid103
# Epoch 17/24-iterating-valid104
# Epoch 17/24-iterating-valid105
# Epoch 17/24-iterating-valid106
# Epoch 17/24-iterating-valid107
# Epoch 17/24-iterating-valid108
# Epoch 17/24-iterating-valid109
# valid Loss: 0.0055 Acc: 0.9989
#
# Epoch 18/24
# ----------
# Epoch 18/24-iterating-train0
# Epoch 18/24-iterating-train1
# Epoch 18/24-iterating-train2
# Epoch 18/24-iterating-train3
# Epoch 18/24-iterating-train4
# Epoch 18/24-iterating-train5
# Epoch 18/24-iterating-train6
# Epoch 18/24-iterating-train7
# Epoch 18/24-iterating-train8
# Epoch 18/24-iterating-train9
# Epoch 18/24-iterating-train10
# Epoch 18/24-iterating-train11
# Epoch 18/24-iterating-train12
# Epoch 18/24-iterating-train13
# Epoch 18/24-iterating-train14
# Epoch 18/24-iterating-train15
# Epoch 18/24-iterating-train16
# Epoch 18/24-iterating-train17
# Epoch 18/24-iterating-train18
# Epoch 18/24-iterating-train19
# Epoch 18/24-iterating-train20
# Epoch 18/24-iterating-train21
# Epoch 18/24-iterating-train22
# Epoch 18/24-iterating-train23
# Epoch 18/24-iterating-train24
# Epoch 18/24-iterating-train25
# Epoch 18/24-iterating-train26
# Epoch 18/24-iterating-train27
# Epoch 18/24-iterating-train28
# Epoch 18/24-iterating-train29
# Epoch 18/24-iterating-train30
# Epoch 18/24-iterating-train31
# Epoch 18/24-iterating-train32
# Epoch 18/24-iterating-train33
# Epoch 18/24-iterating-train34
# Epoch 18/24-iterating-train35
# Epoch 18/24-iterating-train36
# Epoch 18/24-iterating-train37
# Epoch 18/24-iterating-train38
# Epoch 18/24-iterating-train39
# Epoch 18/24-iterating-train40
# Epoch 18/24-iterating-train41
# Epoch 18/24-iterating-train42
# Epoch 18/24-iterating-train43
# Epoch 18/24-iterating-train44
# Epoch 18/24-iterating-train45
# Epoch 18/24-iterating-train46
# Epoch 18/24-iterating-train47
# Epoch 18/24-iterating-train48
# Epoch 18/24-iterating-train49
# Epoch 18/24-iterating-train50
# Epoch 18/24-iterating-train51
# Epoch 18/24-iterating-train52
# Epoch 18/24-iterating-train53
# Epoch 18/24-iterating-train54
# Epoch 18/24-iterating-train55
# Epoch 18/24-iterating-train56
# Epoch 18/24-iterating-train57
# Epoch 18/24-iterating-train58
# Epoch 18/24-iterating-train59
# Epoch 18/24-iterating-train60
# Epoch 18/24-iterating-train61
# Epoch 18/24-iterating-train62
# Epoch 18/24-iterating-train63
# Epoch 18/24-iterating-train64
# Epoch 18/24-iterating-train65
# Epoch 18/24-iterating-train66
# Epoch 18/24-iterating-train67
# Epoch 18/24-iterating-train68
# Epoch 18/24-iterating-train69
# Epoch 18/24-iterating-train70
# Epoch 18/24-iterating-train71
# Epoch 18/24-iterating-train72
# Epoch 18/24-iterating-train73
# Epoch 18/24-iterating-train74
# Epoch 18/24-iterating-train75
# Epoch 18/24-iterating-train76
# Epoch 18/24-iterating-train77
# Epoch 18/24-iterating-train78
# Epoch 18/24-iterating-train79
# Epoch 18/24-iterating-train80
# Epoch 18/24-iterating-train81
# Epoch 18/24-iterating-train82
# Epoch 18/24-iterating-train83
# Epoch 18/24-iterating-train84
# Epoch 18/24-iterating-train85
# Epoch 18/24-iterating-train86
# Epoch 18/24-iterating-train87
# Epoch 18/24-iterating-train88
# Epoch 18/24-iterating-train89
# Epoch 18/24-iterating-train90
# Epoch 18/24-iterating-train91
# Epoch 18/24-iterating-train92
# Epoch 18/24-iterating-train93
# Epoch 18/24-iterating-train94
# Epoch 18/24-iterating-train95
# Epoch 18/24-iterating-train96
# Epoch 18/24-iterating-train97
# Epoch 18/24-iterating-train98
# Epoch 18/24-iterating-train99
# Epoch 18/24-iterating-train100
# Epoch 18/24-iterating-train101
# Epoch 18/24-iterating-train102
# Epoch 18/24-iterating-train103
# Epoch 18/24-iterating-train104
# Epoch 18/24-iterating-train105
# Epoch 18/24-iterating-train106
# Epoch 18/24-iterating-train107
# Epoch 18/24-iterating-train108
# Epoch 18/24-iterating-train109
# Epoch 18/24-iterating-train110
# Epoch 18/24-iterating-train111
# Epoch 18/24-iterating-train112
# Epoch 18/24-iterating-train113
# Epoch 18/24-iterating-train114
# Epoch 18/24-iterating-train115
# Epoch 18/24-iterating-train116
# Epoch 18/24-iterating-train117
# Epoch 18/24-iterating-train118
# Epoch 18/24-iterating-train119
# Epoch 18/24-iterating-train120
# Epoch 18/24-iterating-train121
# Epoch 18/24-iterating-train122
# Epoch 18/24-iterating-train123
# Epoch 18/24-iterating-train124
# Epoch 18/24-iterating-train125
# Epoch 18/24-iterating-train126
# Epoch 18/24-iterating-train127
# Epoch 18/24-iterating-train128
# Epoch 18/24-iterating-train129
# Epoch 18/24-iterating-train130
# Epoch 18/24-iterating-train131
# Epoch 18/24-iterating-train132
# Epoch 18/24-iterating-train133
# Epoch 18/24-iterating-train134
# Epoch 18/24-iterating-train135
# Epoch 18/24-iterating-train136
# Epoch 18/24-iterating-train137
# Epoch 18/24-iterating-train138
# Epoch 18/24-iterating-train139
# Epoch 18/24-iterating-train140
# Epoch 18/24-iterating-train141
# Epoch 18/24-iterating-train142
# Epoch 18/24-iterating-train143
# Epoch 18/24-iterating-train144
# Epoch 18/24-iterating-train145
# Epoch 18/24-iterating-train146
# Epoch 18/24-iterating-train147
# Epoch 18/24-iterating-train148
# Epoch 18/24-iterating-train149
# Epoch 18/24-iterating-train150
# Epoch 18/24-iterating-train151
# Epoch 18/24-iterating-train152
# Epoch 18/24-iterating-train153
# Epoch 18/24-iterating-train154
# Epoch 18/24-iterating-train155
# Epoch 18/24-iterating-train156
# Epoch 18/24-iterating-train157
# Epoch 18/24-iterating-train158
# Epoch 18/24-iterating-train159
# Epoch 18/24-iterating-train160
# Epoch 18/24-iterating-train161
# Epoch 18/24-iterating-train162
# Epoch 18/24-iterating-train163
# Epoch 18/24-iterating-train164
# Epoch 18/24-iterating-train165
# Epoch 18/24-iterating-train166
# Epoch 18/24-iterating-train167
# Epoch 18/24-iterating-train168
# Epoch 18/24-iterating-train169
# Epoch 18/24-iterating-train170
# Epoch 18/24-iterating-train171
# Epoch 18/24-iterating-train172
# Epoch 18/24-iterating-train173
# Epoch 18/24-iterating-train174
# Epoch 18/24-iterating-train175
# Epoch 18/24-iterating-train176
# Epoch 18/24-iterating-train177
# Epoch 18/24-iterating-train178
# Epoch 18/24-iterating-train179
# Epoch 18/24-iterating-train180
# Epoch 18/24-iterating-train181
# Epoch 18/24-iterating-train182
# Epoch 18/24-iterating-train183
# Epoch 18/24-iterating-train184
# Epoch 18/24-iterating-train185
# Epoch 18/24-iterating-train186
# Epoch 18/24-iterating-train187
# Epoch 18/24-iterating-train188
# Epoch 18/24-iterating-train189
# Epoch 18/24-iterating-train190
# Epoch 18/24-iterating-train191
# Epoch 18/24-iterating-train192
# Epoch 18/24-iterating-train193
# Epoch 18/24-iterating-train194
# Epoch 18/24-iterating-train195
# Epoch 18/24-iterating-train196
# Epoch 18/24-iterating-train197
# Epoch 18/24-iterating-train198
# Epoch 18/24-iterating-train199
# Epoch 18/24-iterating-train200
# Epoch 18/24-iterating-train201
# Epoch 18/24-iterating-train202
# Epoch 18/24-iterating-train203
# Epoch 18/24-iterating-train204
# Epoch 18/24-iterating-train205
# Epoch 18/24-iterating-train206
# Epoch 18/24-iterating-train207
# Epoch 18/24-iterating-train208
# Epoch 18/24-iterating-train209
# Epoch 18/24-iterating-train210
# Epoch 18/24-iterating-train211
# Epoch 18/24-iterating-train212
# Epoch 18/24-iterating-train213
# Epoch 18/24-iterating-train214
# Epoch 18/24-iterating-train215
# Epoch 18/24-iterating-train216
# Epoch 18/24-iterating-train217
# Epoch 18/24-iterating-train218
# Epoch 18/24-iterating-train219
# Epoch 18/24-iterating-train220
# Epoch 18/24-iterating-train221
# Epoch 18/24-iterating-train222
# Epoch 18/24-iterating-train223
# Epoch 18/24-iterating-train224
# Epoch 18/24-iterating-train225
# Epoch 18/24-iterating-train226
# Epoch 18/24-iterating-train227
# Epoch 18/24-iterating-train228
# Epoch 18/24-iterating-train229
# Epoch 18/24-iterating-train230
# Epoch 18/24-iterating-train231
# Epoch 18/24-iterating-train232
# Epoch 18/24-iterating-train233
# Epoch 18/24-iterating-train234
# Epoch 18/24-iterating-train235
# Epoch 18/24-iterating-train236
# Epoch 18/24-iterating-train237
# Epoch 18/24-iterating-train238
# Epoch 18/24-iterating-train239
# Epoch 18/24-iterating-train240
# Epoch 18/24-iterating-train241
# Epoch 18/24-iterating-train242
# Epoch 18/24-iterating-train243
# Epoch 18/24-iterating-train244
# Epoch 18/24-iterating-train245
# Epoch 18/24-iterating-train246
# Epoch 18/24-iterating-train247
# Epoch 18/24-iterating-train248
# Epoch 18/24-iterating-train249
# Epoch 18/24-iterating-train250
# Epoch 18/24-iterating-train251
# Epoch 18/24-iterating-train252
# Epoch 18/24-iterating-train253
# Epoch 18/24-iterating-train254
# Epoch 18/24-iterating-train255
# Epoch 18/24-iterating-train256
# Epoch 18/24-iterating-train257
# Epoch 18/24-iterating-train258
# Epoch 18/24-iterating-train259
# Epoch 18/24-iterating-train260
# Epoch 18/24-iterating-train261
# Epoch 18/24-iterating-train262
# Epoch 18/24-iterating-train263
# Epoch 18/24-iterating-train264
# Epoch 18/24-iterating-train265
# Epoch 18/24-iterating-train266
# Epoch 18/24-iterating-train267
# Epoch 18/24-iterating-train268
# Epoch 18/24-iterating-train269
# Epoch 18/24-iterating-train270
# Epoch 18/24-iterating-train271
# Epoch 18/24-iterating-train272
# Epoch 18/24-iterating-train273
# Epoch 18/24-iterating-train274
# Epoch 18/24-iterating-train275
# Epoch 18/24-iterating-train276
# Epoch 18/24-iterating-train277
# Epoch 18/24-iterating-train278
# Epoch 18/24-iterating-train279
# Epoch 18/24-iterating-train280
# Epoch 18/24-iterating-train281
# Epoch 18/24-iterating-train282
# Epoch 18/24-iterating-train283
# Epoch 18/24-iterating-train284
# Epoch 18/24-iterating-train285
# Epoch 18/24-iterating-train286
# Epoch 18/24-iterating-train287
# Epoch 18/24-iterating-train288
# Epoch 18/24-iterating-train289
# Epoch 18/24-iterating-train290
# Epoch 18/24-iterating-train291
# Epoch 18/24-iterating-train292
# Epoch 18/24-iterating-train293
# Epoch 18/24-iterating-train294
# Epoch 18/24-iterating-train295
# Epoch 18/24-iterating-train296
# Epoch 18/24-iterating-train297
# Epoch 18/24-iterating-train298
# Epoch 18/24-iterating-train299
# Epoch 18/24-iterating-train300
# Epoch 18/24-iterating-train301
# Epoch 18/24-iterating-train302
# Epoch 18/24-iterating-train303
# Epoch 18/24-iterating-train304
# Epoch 18/24-iterating-train305
# Epoch 18/24-iterating-train306
# Epoch 18/24-iterating-train307
# Epoch 18/24-iterating-train308
# Epoch 18/24-iterating-train309
# Epoch 18/24-iterating-train310
# Epoch 18/24-iterating-train311
# Epoch 18/24-iterating-train312
# Epoch 18/24-iterating-train313
# Epoch 18/24-iterating-train314
# Epoch 18/24-iterating-train315
# Epoch 18/24-iterating-train316
# Epoch 18/24-iterating-train317
# Epoch 18/24-iterating-train318
# Epoch 18/24-iterating-train319
# Epoch 18/24-iterating-train320
# Epoch 18/24-iterating-train321
# Epoch 18/24-iterating-train322
# Epoch 18/24-iterating-train323
# Epoch 18/24-iterating-train324
# Epoch 18/24-iterating-train325
# Epoch 18/24-iterating-train326
# Epoch 18/24-iterating-train327
# Epoch 18/24-iterating-train328
# Epoch 18/24-iterating-train329
# Epoch 18/24-iterating-train330
# Epoch 18/24-iterating-train331
# Epoch 18/24-iterating-train332
# Epoch 18/24-iterating-train333
# Epoch 18/24-iterating-train334
# Epoch 18/24-iterating-train335
# Epoch 18/24-iterating-train336
# Epoch 18/24-iterating-train337
# Epoch 18/24-iterating-train338
# Epoch 18/24-iterating-train339
# Epoch 18/24-iterating-train340
# Epoch 18/24-iterating-train341
# Epoch 18/24-iterating-train342
# Epoch 18/24-iterating-train343
# Epoch 18/24-iterating-train344
# Epoch 18/24-iterating-train345
# Epoch 18/24-iterating-train346
# Epoch 18/24-iterating-train347
# Epoch 18/24-iterating-train348
# Epoch 18/24-iterating-train349
# Epoch 18/24-iterating-train350
# Epoch 18/24-iterating-train351
# Epoch 18/24-iterating-train352
# Epoch 18/24-iterating-train353
# Epoch 18/24-iterating-train354
# Epoch 18/24-iterating-train355
# Epoch 18/24-iterating-train356
# Epoch 18/24-iterating-train357
# Epoch 18/24-iterating-train358
# Epoch 18/24-iterating-train359
# Epoch 18/24-iterating-train360
# Epoch 18/24-iterating-train361
# Epoch 18/24-iterating-train362
# Epoch 18/24-iterating-train363
# Epoch 18/24-iterating-train364
# Epoch 18/24-iterating-train365
# Epoch 18/24-iterating-train366
# Epoch 18/24-iterating-train367
# Epoch 18/24-iterating-train368
# Epoch 18/24-iterating-train369
# Epoch 18/24-iterating-train370
# Epoch 18/24-iterating-train371
# Epoch 18/24-iterating-train372
# Epoch 18/24-iterating-train373
# Epoch 18/24-iterating-train374
# Epoch 18/24-iterating-train375
# Epoch 18/24-iterating-train376
# Epoch 18/24-iterating-train377
# Epoch 18/24-iterating-train378
# Epoch 18/24-iterating-train379
# Epoch 18/24-iterating-train380
# Epoch 18/24-iterating-train381
# Epoch 18/24-iterating-train382
# Epoch 18/24-iterating-train383
# Epoch 18/24-iterating-train384
# Epoch 18/24-iterating-train385
# Epoch 18/24-iterating-train386
# Epoch 18/24-iterating-train387
# Epoch 18/24-iterating-train388
# Epoch 18/24-iterating-train389
# Epoch 18/24-iterating-train390
# Epoch 18/24-iterating-train391
# Epoch 18/24-iterating-train392
# Epoch 18/24-iterating-train393
# Epoch 18/24-iterating-train394
# Epoch 18/24-iterating-train395
# Epoch 18/24-iterating-train396
# Epoch 18/24-iterating-train397
# Epoch 18/24-iterating-train398
# Epoch 18/24-iterating-train399
# Epoch 18/24-iterating-train400
# Epoch 18/24-iterating-train401
# Epoch 18/24-iterating-train402
# Epoch 18/24-iterating-train403
# Epoch 18/24-iterating-train404
# Epoch 18/24-iterating-train405
# Epoch 18/24-iterating-train406
# Epoch 18/24-iterating-train407
# Epoch 18/24-iterating-train408
# Epoch 18/24-iterating-train409
# Epoch 18/24-iterating-train410
# Epoch 18/24-iterating-train411
# Epoch 18/24-iterating-train412
# Epoch 18/24-iterating-train413
# Epoch 18/24-iterating-train414
# Epoch 18/24-iterating-train415
# Epoch 18/24-iterating-train416
# Epoch 18/24-iterating-train417
# Epoch 18/24-iterating-train418
# Epoch 18/24-iterating-train419
# Epoch 18/24-iterating-train420
# Epoch 18/24-iterating-train421
# Epoch 18/24-iterating-train422
# Epoch 18/24-iterating-train423
# Epoch 18/24-iterating-train424
# Epoch 18/24-iterating-train425
# Epoch 18/24-iterating-train426
# Epoch 18/24-iterating-train427
# Epoch 18/24-iterating-train428
# Epoch 18/24-iterating-train429
# Epoch 18/24-iterating-train430
# Epoch 18/24-iterating-train431
# Epoch 18/24-iterating-train432
# Epoch 18/24-iterating-train433
# Epoch 18/24-iterating-train434
# Epoch 18/24-iterating-train435
# ...
# Epoch 24/24-iterating-train30
# Epoch 24/24-iterating-train31
# Epoch 24/24-iterating-train32
# Epoch 24/24-iterating-train33
# Epoch 24/24-iterating-train34
# Epoch 24/24-iterating-train35
# Epoch 24/24-iterating-train36
# Epoch 24/24-iterating-train37
# Epoch 24/24-iterating-train38
# Epoch 24/24-iterating-train39
# Epoch 24/24-iterating-train40
# Epoch 24/24-iterating-train41
# Epoch 24/24-iterating-train42
# Epoch 24/24-iterating-train43
# Epoch 24/24-iterating-train44
# Epoch 24/24-iterating-train45
# Epoch 24/24-iterating-train46
# Epoch 24/24-iterating-train47
# Epoch 24/24-iterating-train48
# Epoch 24/24-iterating-train49
# Epoch 24/24-iterating-train50
# Epoch 24/24-iterating-train51
# Epoch 24/24-iterating-train52
# Epoch 24/24-iterating-train53
# Epoch 24/24-iterating-train54
# Epoch 24/24-iterating-train55
# Epoch 24/24-iterating-train56
# Epoch 24/24-iterating-train57
# Epoch 24/24-iterating-train58
# Epoch 24/24-iterating-train59
# Epoch 24/24-iterating-train60
# Epoch 24/24-iterating-train61
# Epoch 24/24-iterating-train62
# Epoch 24/24-iterating-train63
# Epoch 24/24-iterating-train64
# Epoch 24/24-iterating-train65
# Epoch 24/24-iterating-train66
# Epoch 24/24-iterating-train67
# Epoch 24/24-iterating-train68
# Epoch 24/24-iterating-train69
# Epoch 24/24-iterating-train70
# Epoch 24/24-iterating-train71
# Epoch 24/24-iterating-train72
# Epoch 24/24-iterating-train73
# Epoch 24/24-iterating-train74
# Epoch 24/24-iterating-train75
# Epoch 24/24-iterating-train76
# Epoch 24/24-iterating-train77
# Epoch 24/24-iterating-train78
# Epoch 24/24-iterating-train79
# Epoch 24/24-iterating-train80
# Epoch 24/24-iterating-train81
# Epoch 24/24-iterating-train82
# Epoch 24/24-iterating-train83
# Epoch 24/24-iterating-train84
# Epoch 24/24-iterating-train85
# Epoch 24/24-iterating-train86
# Epoch 24/24-iterating-train87
# Epoch 24/24-iterating-train88
# Epoch 24/24-iterating-train89
# Epoch 24/24-iterating-train90
# Epoch 24/24-iterating-train91
# Epoch 24/24-iterating-train92
# Epoch 24/24-iterating-train93
# Epoch 24/24-iterating-train94
# Epoch 24/24-iterating-train95
# Epoch 24/24-iterating-train96
# Epoch 24/24-iterating-train97
# Epoch 24/24-iterating-train98
# Epoch 24/24-iterating-train99
# Epoch 24/24-iterating-train100
# Epoch 24/24-iterating-train101
# Epoch 24/24-iterating-train102
# Epoch 24/24-iterating-train103
# Epoch 24/24-iterating-train104
# Epoch 24/24-iterating-train105
# Epoch 24/24-iterating-train106
# Epoch 24/24-iterating-train107
# Epoch 24/24-iterating-train108
# Epoch 24/24-iterating-train109
# Epoch 24/24-iterating-train110
# Epoch 24/24-iterating-train111
# Epoch 24/24-iterating-train112
# Epoch 24/24-iterating-train113
# Epoch 24/24-iterating-train114
# Epoch 24/24-iterating-train115
# Epoch 24/24-iterating-train116
# Epoch 24/24-iterating-train117
# Epoch 24/24-iterating-train118
# Epoch 24/24-iterating-train119
# Epoch 24/24-iterating-train120
# Epoch 24/24-iterating-train121
# Epoch 24/24-iterating-train122
# Epoch 24/24-iterating-train123
# Epoch 24/24-iterating-train124
# Epoch 24/24-iterating-train125
# Epoch 24/24-iterating-train126
# Epoch 24/24-iterating-train127
# Epoch 24/24-iterating-train128
# Epoch 24/24-iterating-train129
# Epoch 24/24-iterating-train130
# Epoch 24/24-iterating-train131
# Epoch 24/24-iterating-train132
# Epoch 24/24-iterating-train133
# Epoch 24/24-iterating-train134
# Epoch 24/24-iterating-train135
# Epoch 24/24-iterating-train136
# Epoch 24/24-iterating-train137
# Epoch 24/24-iterating-train138
# Epoch 24/24-iterating-train139
# Epoch 24/24-iterating-train140
# Epoch 24/24-iterating-train141
# Epoch 24/24-iterating-train142
# Epoch 24/24-iterating-train143
# Epoch 24/24-iterating-train144
# Epoch 24/24-iterating-train145
# Epoch 24/24-iterating-train146
# Epoch 24/24-iterating-train147
# Epoch 24/24-iterating-train148
# Epoch 24/24-iterating-train149
# Epoch 24/24-iterating-train150
# Epoch 24/24-iterating-train151
# Epoch 24/24-iterating-train152
# Epoch 24/24-iterating-train153
# Epoch 24/24-iterating-train154
# Epoch 24/24-iterating-train155
# Epoch 24/24-iterating-train156
# Epoch 24/24-iterating-train157
# Epoch 24/24-iterating-train158
# Epoch 24/24-iterating-train159
# Epoch 24/24-iterating-train160
# Epoch 24/24-iterating-train161
# Epoch 24/24-iterating-train162
# Epoch 24/24-iterating-train163
# Epoch 24/24-iterating-train164
# Epoch 24/24-iterating-train165
# Epoch 24/24-iterating-train166
# Epoch 24/24-iterating-train167
# Epoch 24/24-iterating-train168
# Epoch 24/24-iterating-train169
# Epoch 24/24-iterating-train170
# Epoch 24/24-iterating-train171
# Epoch 24/24-iterating-train172
# Epoch 24/24-iterating-train173
# Epoch 24/24-iterating-train174
# Epoch 24/24-iterating-train175
# Epoch 24/24-iterating-train176
# Epoch 24/24-iterating-train177
# Epoch 24/24-iterating-train178
# Epoch 24/24-iterating-train179
# Epoch 24/24-iterating-train180
# Epoch 24/24-iterating-train181
# Epoch 24/24-iterating-train182
# Epoch 24/24-iterating-train183
# Epoch 24/24-iterating-train184
# Epoch 24/24-iterating-train185
# Epoch 24/24-iterating-train186
# Epoch 24/24-iterating-train187
# Epoch 24/24-iterating-train188
# Epoch 24/24-iterating-train189
# Epoch 24/24-iterating-train190
# Epoch 24/24-iterating-train191
# Epoch 24/24-iterating-train192
# Epoch 24/24-iterating-train193
# Epoch 24/24-iterating-train194
# Epoch 24/24-iterating-train195
# Epoch 24/24-iterating-train196
# Epoch 24/24-iterating-train197
# Epoch 24/24-iterating-train198
# Epoch 24/24-iterating-train199
# Epoch 24/24-iterating-train200
# Epoch 24/24-iterating-train201
# Epoch 24/24-iterating-train202
# Epoch 24/24-iterating-train203
# Epoch 24/24-iterating-train204
# Epoch 24/24-iterating-train205
# Epoch 24/24-iterating-train206
# Epoch 24/24-iterating-train207
# Epoch 24/24-iterating-train208
# Epoch 24/24-iterating-train209
# Epoch 24/24-iterating-train210
# Epoch 24/24-iterating-train211
# Epoch 24/24-iterating-train212
# Epoch 24/24-iterating-train213
# Epoch 24/24-iterating-train214
# Epoch 24/24-iterating-train215
# Epoch 24/24-iterating-train216
# Epoch 24/24-iterating-train217
# Epoch 24/24-iterating-train218
# Epoch 24/24-iterating-train219
# Epoch 24/24-iterating-train220
# Epoch 24/24-iterating-train221
# Epoch 24/24-iterating-train222
# Epoch 24/24-iterating-train223
# Epoch 24/24-iterating-train224
# Epoch 24/24-iterating-train225
# Epoch 24/24-iterating-train226
# Epoch 24/24-iterating-train227
# Epoch 24/24-iterating-train228
# Epoch 24/24-iterating-train229
# Epoch 24/24-iterating-train230
# Epoch 24/24-iterating-train231
# Epoch 24/24-iterating-train232
# Epoch 24/24-iterating-train233
# Epoch 24/24-iterating-train234
# Epoch 24/24-iterating-train235
# Epoch 24/24-iterating-train236
# Epoch 24/24-iterating-train237
# Epoch 24/24-iterating-train238
# Epoch 24/24-iterating-train239
# Epoch 24/24-iterating-train240
# Epoch 24/24-iterating-train241
# Epoch 24/24-iterating-train242
# Epoch 24/24-iterating-train243
# Epoch 24/24-iterating-train244
# Epoch 24/24-iterating-train245
# Epoch 24/24-iterating-train246
# Epoch 24/24-iterating-train247
# Epoch 24/24-iterating-train248
# Epoch 24/24-iterating-train249
# Epoch 24/24-iterating-train250
# Epoch 24/24-iterating-train251
# Epoch 24/24-iterating-train252
# Epoch 24/24-iterating-train253
# Epoch 24/24-iterating-train254
# Epoch 24/24-iterating-train255
# Epoch 24/24-iterating-train256
# Epoch 24/24-iterating-train257
# Epoch 24/24-iterating-train258
# Epoch 24/24-iterating-train259
# Epoch 24/24-iterating-train260
# Epoch 24/24-iterating-train261
# Epoch 24/24-iterating-train262
# Epoch 24/24-iterating-train263
# Epoch 24/24-iterating-train264
# Epoch 24/24-iterating-train265
# Epoch 24/24-iterating-train266
# Epoch 24/24-iterating-train267
# Epoch 24/24-iterating-train268
# Epoch 24/24-iterating-train269
# Epoch 24/24-iterating-train270
# Epoch 24/24-iterating-train271
# Epoch 24/24-iterating-train272
# Epoch 24/24-iterating-train273
# Epoch 24/24-iterating-train274
# Epoch 24/24-iterating-train275
# Epoch 24/24-iterating-train276
# Epoch 24/24-iterating-train277
# Epoch 24/24-iterating-train278
# Epoch 24/24-iterating-train279
# Epoch 24/24-iterating-train280
# Epoch 24/24-iterating-train281
# Epoch 24/24-iterating-train282
# Epoch 24/24-iterating-train283
# Epoch 24/24-iterating-train284
# Epoch 24/24-iterating-train285
# Epoch 24/24-iterating-train286
# Epoch 24/24-iterating-train287
# Epoch 24/24-iterating-train288
# Epoch 24/24-iterating-train289
# Epoch 24/24-iterating-train290
# Epoch 24/24-iterating-train291
# Epoch 24/24-iterating-train292
# Epoch 24/24-iterating-train293
# Epoch 24/24-iterating-train294
# Epoch 24/24-iterating-train295
# Epoch 24/24-iterating-train296
# Epoch 24/24-iterating-train297
# Epoch 24/24-iterating-train298
# Epoch 24/24-iterating-train299
# Epoch 24/24-iterating-train300
# Epoch 24/24-iterating-train301
# Epoch 24/24-iterating-train302
# Epoch 24/24-iterating-train303
# Epoch 24/24-iterating-train304
# Epoch 24/24-iterating-train305
# Epoch 24/24-iterating-train306
# Epoch 24/24-iterating-train307
# Epoch 24/24-iterating-train308
# Epoch 24/24-iterating-train309
# Epoch 24/24-iterating-train310
# Epoch 24/24-iterating-train311
# Epoch 24/24-iterating-train312
# Epoch 24/24-iterating-train313
# Epoch 24/24-iterating-train314
# Epoch 24/24-iterating-train315
# Epoch 24/24-iterating-train316
# Epoch 24/24-iterating-train317
# Epoch 24/24-iterating-train318
# Epoch 24/24-iterating-train319
# Epoch 24/24-iterating-train320
# Epoch 24/24-iterating-train321
# Epoch 24/24-iterating-train322
# Epoch 24/24-iterating-train323
# Epoch 24/24-iterating-train324
# Epoch 24/24-iterating-train325
# Epoch 24/24-iterating-train326
# Epoch 24/24-iterating-train327
# Epoch 24/24-iterating-train328
# Epoch 24/24-iterating-train329
# Epoch 24/24-iterating-train330
# Epoch 24/24-iterating-train331
# Epoch 24/24-iterating-train332
# Epoch 24/24-iterating-train333
# Epoch 24/24-iterating-train334
# Epoch 24/24-iterating-train335
# Epoch 24/24-iterating-train336
# Epoch 24/24-iterating-train337
# Epoch 24/24-iterating-train338
# Epoch 24/24-iterating-train339
# Epoch 24/24-iterating-train340
# Epoch 24/24-iterating-train341
# Epoch 24/24-iterating-train342
# Epoch 24/24-iterating-train343
# Epoch 24/24-iterating-train344
# Epoch 24/24-iterating-train345
# Epoch 24/24-iterating-train346
# Epoch 24/24-iterating-train347
# Epoch 24/24-iterating-train348
# Epoch 24/24-iterating-train349
# Epoch 24/24-iterating-train350
# Epoch 24/24-iterating-train351
# Epoch 24/24-iterating-train352
# Epoch 24/24-iterating-train353
# Epoch 24/24-iterating-train354
# Epoch 24/24-iterating-train355
# Epoch 24/24-iterating-train356
# Epoch 24/24-iterating-train357
# Epoch 24/24-iterating-train358
# Epoch 24/24-iterating-train359
# Epoch 24/24-iterating-train360
# Epoch 24/24-iterating-train361
# Epoch 24/24-iterating-train362
# Epoch 24/24-iterating-train363
# Epoch 24/24-iterating-train364
# Epoch 24/24-iterating-train365
# Epoch 24/24-iterating-train366
# Epoch 24/24-iterating-train367
# Epoch 24/24-iterating-train368
# Epoch 24/24-iterating-train369
# Epoch 24/24-iterating-train370
# Epoch 24/24-iterating-train371
# Epoch 24/24-iterating-train372
# Epoch 24/24-iterating-train373
# Epoch 24/24-iterating-train374
# Epoch 24/24-iterating-train375
# Epoch 24/24-iterating-train376
# Epoch 24/24-iterating-train377
# Epoch 24/24-iterating-train378
# Epoch 24/24-iterating-train379
# Epoch 24/24-iterating-train380
# Epoch 24/24-iterating-train381
# Epoch 24/24-iterating-train382
# Epoch 24/24-iterating-train383
# Epoch 24/24-iterating-train384
# Epoch 24/24-iterating-train385
# Epoch 24/24-iterating-train386
# Epoch 24/24-iterating-train387
# Epoch 24/24-iterating-train388
# Epoch 24/24-iterating-train389
# Epoch 24/24-iterating-train390
# Epoch 24/24-iterating-train391
# Epoch 24/24-iterating-train392
# Epoch 24/24-iterating-train393
# Epoch 24/24-iterating-train394
# Epoch 24/24-iterating-train395
# Epoch 24/24-iterating-train396
# Epoch 24/24-iterating-train397
# Epoch 24/24-iterating-train398
# Epoch 24/24-iterating-train399
# Epoch 24/24-iterating-train400
# Epoch 24/24-iterating-train401
# Epoch 24/24-iterating-train402
# Epoch 24/24-iterating-train403
# Epoch 24/24-iterating-train404
# Epoch 24/24-iterating-train405
# Epoch 24/24-iterating-train406
# Epoch 24/24-iterating-train407
# Epoch 24/24-iterating-train408
# Epoch 24/24-iterating-train409
# Epoch 24/24-iterating-train410
# Epoch 24/24-iterating-train411
# Epoch 24/24-iterating-train412
# Epoch 24/24-iterating-train413
# Epoch 24/24-iterating-train414
# Epoch 24/24-iterating-train415
# Epoch 24/24-iterating-train416
# Epoch 24/24-iterating-train417
# Epoch 24/24-iterating-train418
# Epoch 24/24-iterating-train419
# Epoch 24/24-iterating-train420
# Epoch 24/24-iterating-train421
# Epoch 24/24-iterating-train422
# Epoch 24/24-iterating-train423
# Epoch 24/24-iterating-train424
# Epoch 24/24-iterating-train425
# Epoch 24/24-iterating-train426
# Epoch 24/24-iterating-train427
# Epoch 24/24-iterating-train428
# Epoch 24/24-iterating-train429
# Epoch 24/24-iterating-train430
# Epoch 24/24-iterating-train431
# Epoch 24/24-iterating-train432
# Epoch 24/24-iterating-train433
# Epoch 24/24-iterating-train434
# Epoch 24/24-iterating-train435
# Epoch 24/24-iterating-train436
# train Loss: 0.0307 Acc: 0.9897
# Epoch 24/24-iterating-valid0
# Epoch 24/24-iterating-valid1
# Epoch 24/24-iterating-valid2
# Epoch 24/24-iterating-valid3
# Epoch 24/24-iterating-valid4
# Epoch 24/24-iterating-valid5
# Epoch 24/24-iterating-valid6
# Epoch 24/24-iterating-valid7
# Epoch 24/24-iterating-valid8
# Epoch 24/24-iterating-valid9
# Epoch 24/24-iterating-valid10
# Epoch 24/24-iterating-valid11
# Epoch 24/24-iterating-valid12
# Epoch 24/24-iterating-valid13
# Epoch 24/24-iterating-valid14
# Epoch 24/24-iterating-valid15
# Epoch 24/24-iterating-valid16
# Epoch 24/24-iterating-valid17
# Epoch 24/24-iterating-valid18
# Epoch 24/24-iterating-valid19
# Epoch 24/24-iterating-valid20
# Epoch 24/24-iterating-valid21
# Epoch 24/24-iterating-valid22
# Epoch 24/24-iterating-valid23
# Epoch 24/24-iterating-valid24
# Epoch 24/24-iterating-valid25
# Epoch 24/24-iterating-valid26
# Epoch 24/24-iterating-valid27
# Epoch 24/24-iterating-valid28
# Epoch 24/24-iterating-valid29
# Epoch 24/24-iterating-valid30
# Epoch 24/24-iterating-valid31
# Epoch 24/24-iterating-valid32
# Epoch 24/24-iterating-valid33
# Epoch 24/24-iterating-valid34
# Epoch 24/24-iterating-valid35
# Epoch 24/24-iterating-valid36
# Epoch 24/24-iterating-valid37
# Epoch 24/24-iterating-valid38
# Epoch 24/24-iterating-valid39
# Epoch 24/24-iterating-valid40
# Epoch 24/24-iterating-valid41
# Epoch 24/24-iterating-valid42
# Epoch 24/24-iterating-valid43
# Epoch 24/24-iterating-valid44
# Epoch 24/24-iterating-valid45
# Epoch 24/24-iterating-valid46
# Epoch 24/24-iterating-valid47
# Epoch 24/24-iterating-valid48
# Epoch 24/24-iterating-valid49
# Epoch 24/24-iterating-valid50
# Epoch 24/24-iterating-valid51
# Epoch 24/24-iterating-valid52
# Epoch 24/24-iterating-valid53
# Epoch 24/24-iterating-valid54
# Epoch 24/24-iterating-valid55
# Epoch 24/24-iterating-valid56
# Epoch 24/24-iterating-valid57
# Epoch 24/24-iterating-valid58
# Epoch 24/24-iterating-valid59
# Epoch 24/24-iterating-valid60
# Epoch 24/24-iterating-valid61
# Epoch 24/24-iterating-valid62
# Epoch 24/24-iterating-valid63
# Epoch 24/24-iterating-valid64
# Epoch 24/24-iterating-valid65
# Epoch 24/24-iterating-valid66
# Epoch 24/24-iterating-valid67
# Epoch 24/24-iterating-valid68
# Epoch 24/24-iterating-valid69
# Epoch 24/24-iterating-valid70
# Epoch 24/24-iterating-valid71
# Epoch 24/24-iterating-valid72
# Epoch 24/24-iterating-valid73
# Epoch 24/24-iterating-valid74
# Epoch 24/24-iterating-valid75
# Epoch 24/24-iterating-valid76
# Epoch 24/24-iterating-valid77
# Epoch 24/24-iterating-valid78
# Epoch 24/24-iterating-valid79
# Epoch 24/24-iterating-valid80
# Epoch 24/24-iterating-valid81
# Epoch 24/24-iterating-valid82
# Epoch 24/24-iterating-valid83
# Epoch 24/24-iterating-valid84
# Epoch 24/24-iterating-valid85
# Epoch 24/24-iterating-valid86
# Epoch 24/24-iterating-valid87
# Epoch 24/24-iterating-valid88
# Epoch 24/24-iterating-valid89
# Epoch 24/24-iterating-valid90
# Epoch 24/24-iterating-valid91
# Epoch 24/24-iterating-valid92
# Epoch 24/24-iterating-valid93
# Epoch 24/24-iterating-valid94
# Epoch 24/24-iterating-valid95
# Epoch 24/24-iterating-valid96
# Epoch 24/24-iterating-valid97
# Epoch 24/24-iterating-valid98
# Epoch 24/24-iterating-valid99
# Epoch 24/24-iterating-valid100
# Epoch 24/24-iterating-valid101
# Epoch 24/24-iterating-valid102
# Epoch 24/24-iterating-valid103
# Epoch 24/24-iterating-valid104
# Epoch 24/24-iterating-valid105
# Epoch 24/24-iterating-valid106
# Epoch 24/24-iterating-valid107
# Epoch 24/24-iterating-valid108
# Epoch 24/24-iterating-valid109
# valid Loss: 0.0055 Acc: 0.9990
#
# Training complete in 96m 2s
# Best val Acc: 0.9993
# Model saved successfully.

# %%
# Load the saved model weights
model.load_state_dict(torch.load('drive/MyDrive/plant_disease_detection/models/efficientnet_v2_S_nightshade_plant_disease_detection_model.pth'))

# Set the model to evaluation mode
model.eval()
# Out:
# EfficientNet(
#   (conv_stem): Conv2dSame(3, 24, kernel_size=(3, 3), stride=(2, 2), bias=False)
#   (bn1): BatchNormAct2d(
#     24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#     (drop): Identity()
#     (act): SiLU(inplace=True)
#   )
#   (blocks): Sequential(
#     (0): Sequential(
#       (0): ConvBnAct(
#         (conv): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (drop_path): Identity()
#       )
#       (1): ConvBnAct(
#         (conv): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (drop_path): Identity()
#       )
#     )
#     (1): Sequential(
#       (0): EdgeResidual(
#         (conv_exp): Conv2dSame(24, 96, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn1): BatchNormAct2d(
#           96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): Identity()
#         (conv_pwl): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNormAct2d(
#           48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (1): EdgeResidual(
#         (conv_exp): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): Identity()
#         (conv_pwl): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNormAct2d(
#           48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (2): EdgeResidual(
#         (conv_exp): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): Identity()
#         (conv_pwl): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNormAct2d(
#           48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (3): EdgeResidual(
#         (conv_exp): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): Identity()
#         (conv_pwl): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNormAct2d(
#           48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (2): Sequential(
#       (0): EdgeResidual(
#         (conv_exp): Conv2dSame(48, 192, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn1): BatchNormAct2d(
#           192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): Identity()
#         (conv_pwl): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNormAct2d(
#           64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (1): EdgeResidual(
#         (conv_exp): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): Identity()
#         (conv_pwl): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNormAct2d(
#           64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (2): EdgeResidual(
#         (conv_exp): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): Identity()
#         (conv_pwl): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNormAct2d(
#           64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (3): EdgeResidual(
#         (conv_exp): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): Identity()
#         (conv_pwl): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNormAct2d(
#           64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (3): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2dSame(256, 256, kernel_size=(3, 3), stride=(2, 2), groups=256, bias=False)
#         (bn2): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#         (bn2): BatchNormAct2d(
#           512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#         (bn2): BatchNormAct2d(
#           512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (3): InvertedResidual(
#         (conv_pw): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#         (bn2): BatchNormAct2d(
#           512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (4): InvertedResidual(
#         (conv_pw): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#         (bn2): BatchNormAct2d(
#           512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (5): InvertedResidual(
#         (conv_pw): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#         (bn2): BatchNormAct2d(
#           512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (4): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=768, bias=False)
#         (bn2): BatchNormAct2d(
#           768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(768, 32, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(32, 768, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#         (bn2): BatchNormAct2d(
#           960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#         (bn2): BatchNormAct2d(
#           960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (3): InvertedResidual(
#         (conv_pw): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#         (bn2): BatchNormAct2d(
#           960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (4): InvertedResidual(
#         (conv_pw): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#         (bn2): BatchNormAct2d(
#           960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (5): InvertedResidual(
#         (conv_pw): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#         (bn2): BatchNormAct2d(
#           960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (6): InvertedResidual(
#         (conv_pw): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#         (bn2): BatchNormAct2d(
#           960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (7): InvertedResidual(
#         (conv_pw): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#         (bn2): BatchNormAct2d(
#           960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (8): InvertedResidual(
#         (conv_pw): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#         (bn2): BatchNormAct2d(
#           960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (5): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2dSame(960, 960, kernel_size=(3, 3), stride=(2, 2), groups=960, bias=False)
#         (bn2): BatchNormAct2d(
#           960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(960, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#         (bn2): BatchNormAct2d(
#           1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#         (bn2): BatchNormAct2d(
#           1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (3): InvertedResidual(
#         (conv_pw): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#         (bn2): BatchNormAct2d(
#           1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (4): InvertedResidual(
#         (conv_pw): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#         (bn2): BatchNormAct2d(
#           1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (5): InvertedResidual(
#         (conv_pw): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#         (bn2): BatchNormAct2d(
#           1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (6): InvertedResidual(
#         (conv_pw): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#         (bn2): BatchNormAct2d(
#           1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (7): InvertedResidual(
#         (conv_pw): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#         (bn2): BatchNormAct2d(
#           1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (8): InvertedResidual(
#         (conv_pw): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#         (bn2): BatchNormAct2d(
#           1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (9): InvertedResidual(
#         (conv_pw): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#         (bn2): BatchNormAct2d(
#           1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (10): InvertedResidual(
#         (conv_pw): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#         (bn2): BatchNormAct2d(
#           1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (11): InvertedResidual(
#         (conv_pw): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#         (bn2): BatchNormAct2d(
#           1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (12): InvertedResidual(
#         (conv_pw): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#         (bn2): BatchNormAct2d(
#           1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (13): InvertedResidual(
#         (conv_pw): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#         (bn2): BatchNormAct2d(
#           1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (14): InvertedResidual(
#         (conv_pw): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#         (bn2): BatchNormAct2d(
#           1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#   )
#   (conv_head): Conv2d(256, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn2): BatchNormAct2d(
#     1280, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#     (drop): Identity()
#     (act): SiLU(inplace=True)
#   )
#   (global_pool): SelectAdaptivePool2d(pool_type=avg, flatten=Flatten(start_dim=1, end_dim=-1))
#   (classifier): Linear(in_features=1280, out_features=15, bias=True)
# )

# %%
# Evaluate the model on the validation set
def evaluate_model(model, dataloader, criterion, device):
    model.eval()  # Set the model to evaluation mode
    running_loss = 0.0
    running_corrects = 0
    all_labels = []
    all_preds = []
    dataset_size = len(dataloader.dataset)

    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)
            loss = criterion(outputs, labels)

            _, preds = torch.max(outputs, 1)
            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)

            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(preds.cpu().numpy())

    epoch_loss = running_loss / dataset_size
    epoch_acc = running_corrects.double() / dataset_size

    all_labels = np.array(all_labels)
    all_preds = np.array(all_preds)

    precision = precision_score(all_labels, all_preds, average='weighted')
    recall = recall_score(all_labels, all_preds, average='weighted')
    f1 = f1_score(all_labels, all_preds, average='weighted')
    accuracy = accuracy_score(all_labels, all_preds)

    print(f"Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}")
    print(f"Precision: {precision:.4f} Recall: {recall:.4f} F1 Score: {f1:.4f} Accuracy: {accuracy:.4f}")

    return epoch_loss, epoch_acc, precision, recall, f1, accuracy

# %%
# Evaluate the model
evaluate_model(model, dataloaders['valid'], criterion, device)
# Out:
# Loss: 0.0055 Acc: 0.9990
# Precision: 0.9990 Recall: 0.9990 F1 Score: 0.9990 Accuracy: 0.9990
# (0.00548334737413265,
#  tensor(0.9990, device='cuda:0', dtype=torch.float64),
#  0.999001296853927,
#  0.998997995991984,
#  0.9989982830732032,
#  0.998997995991984)
